NaN   NaN   NaN   NaN   NaN   NaN
#
# [1084 rows x 6 columns]

# %%
ytrain.dropna(inplace = True)
ytrain
# Out:
#          일     이     삼     사     오     육
# 0      3.0   7.0  14.0  15.0  22.0  38.0
# 1     21.0  26.0  27.0  32.0  34.0  42.0
# 2      1.0   9.0  16.0  23.0  24.0  38.0
# 3     13.0  16.0  23.0  31.0  36.0  44.0
# 4      4.0   8.0  18.0  24.0  37.0  45.0
# ...    ...   ...   ...   ...   ...   ...
# 1078  16.0  24.0  29.0  40.0  41.0  42.0
# 1079  14.0  27.0  30.0  31.0  40.0  42.0
# 1080  11.0  16.0  19.0  21.0  27.0  31.0
# 1081   9.0  13.0  21.0  25.0  32.0  42.0
# 1082  10.0  23.0  29.0  33.0  37.0  40.0
#
# [1083 rows x 6 columns]

# %%
ytrain.astype(int)
# Out:
#        일   이   삼   사   오   육
# 0      3   7  14  15  22  38
# 1     21  26  27  32  34  42
# 2      1   9  16  23  24  38
# 3     13  16  23  31  36  44
# 4      4   8  18  24  37  45
# ...   ..  ..  ..  ..  ..  ..
# 1078  16  24  29  40  41  42
# 1079  14  27  30  31  40  42
# 1080  11  16  19  21  27  31
# 1081   9  13  21  25  32  42
# 1082  10  23  29  33  37  40
#
# [1083 rows x 6 columns]

# %%
from pandas import get_dummies

Xtrain = pd.get_dummies(Xtrain)
Xtest = pd.get_dummies(Xtest)
Xtest
# Out:
#    10  23  29  33  37  40
# 1   1   0   0   0   0   0
# 2   0   1   0   0   0   0
# 3   0   0   1   0   0   0
# 4   0   0   0   1   0   0
# 5   0   0   0   0   1   0
# 6   0   0   0   0   0   1

# %%
from sklearn.model_selection import train_test_split

Xtr, Xval, ytr, yval = train_test_split(Xtrain, ytrain,
                                        test_size = 0.2,
                                        random_state = 202309)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedGroupKFold
kfold = KFold(n_splits = 10, shuffle = True, random_state = 202309)

# %%
# !pip install KNN
# !pip install SVC
# !pip install decisiontree
# !pip install voting
# Out:
# Collecting KNN
#   Downloading KNN-1.0.0.tar.gz (2.4 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: KNN
#   Building wheel for KNN (setup.py) ... done
#   Created wheel for KNN: filename=KNN-1.0.0-py3-none-any.whl size=3111 sha256=e0c2463b6fe0c3d992780c2081cab2136aeda23d59e71ff2dacd1ea0c0f44eff
#   Stored in directory: /root/.cache/pip/wheels/db/f0/9c/9da3fdf7ad3d19587a688434d71dbf38ced30bde9fb2975ff7
# Successfully built KNN
# Installing collected packages: KNN
# Successfully installed KNN-1.0.0
# Collecting SVC
#   Downloading SVC-0.1.tar.gz (1.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: xlrd>=0.9.3 in /usr/local/lib/python3.10/dist-packages (from SVC) (2.0.1)
# Building wheels for collected packages: SVC
#   Building wheel for SVC (setup.py) ... done
#   Created wheel for SVC: filename=SVC-0.1-py3-none-any.whl size=1870 sha256=e63c9d2a7e3cec0c3405a0110ffd2c138690a408ab5bcb2d742c68ff1dd610ad
#   Stored in directory: /root/.cache/pip/wheels/88/51/46/316b33cfa9e39d0749762daa17b6a8646e3050079185747370
# Successfully built SVC
# Installing collected packages: SVC
# Successfully installed SVC-0.1
# Collecting decisiontree
#   Downloading DecisionTree-3.4.3.tar.gz (335 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 335.3/335.3 kB 5.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: decisiontree
#   Building wheel for decisiontree (setup.py) ... done
#   Created wheel for decisiontree: filename=DecisionTree-3.4.3-py3-none-any.whl size=81843 sha256=690411c33cfcf18be947c555ccb9510443e8672651ae93b7d806709e66403045
#   Stored in directory: /root/.cache/pip/wheels/59/d4/29/d88ed8e92d4c96a49d195c034b7f0e7ce74b10531fbfd98555
# Successfully built decisiontree
# Installing collected packages: decisiontree
# Successfully installed decisiontree-3.4.3
# Collecting voting
#   Downloading voting-0.1.3-py2.py3-none-any.whl (8.0 kB)
# Installing collected packages: voting
# Successfully installed voting-0.1.3

# %%
# 머신러닝 알고리즘 분류
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import VotingClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

model1 = KNeighborsClassifier(n_neighbors = 100)
model2 = LogisticRegression(random_state = 202309)
model3 = SVC(random_state = 202309, probability = True)
model4 = DecisionTreeClassifier(random_state = 202309,
                                max_depth = 50)
model5 = RandomForestClassifier(random_state = 202309,
                                max_depth = 2,
                                n_estimators= 5)
model6 = AdaBoostClassifier(random_state = 202309)
model7 = GradientBoostingClassifier(random_state = 202309)
model8 = LGBMClassifier(random_state = 202309)
model9 = XGBClassifier(random_state = 202309, silent = True, verbosity = 0)

# %%
model1.fit(Xtr, ytr)
# model2.fit(Xtr, ytr)
# model3.fit(Xtr, ytr)
model4.fit(Xtr, ytr)
model5.fit(Xtr, ytr)
# model6.fit(Xtr, ytr)
# model7.fit(Xtr, ytr)
# model8.fit(Xtr, ytr)
# model9.fit(Xtr, ytr)
# model10.fit(Xtr, ytr)
# model11.fit(Xtr, ytr)

pred1 = model1.predict(Xval)
# pred2 = model2.predict(Xval)
# pred3 = model3.predict(Xval)
pred4 = model4.predict(Xval)
pred5 = model5.predict(Xval)
# pred6 = model6.predict(Xval)
# pred7 = model7.predict(Xval)
# pred8 = model8.predict(Xval)
# pred9 = model9.predict(Xval)
# pred10 = model10.predict(Xval)
# pred11 = model11.predict(Xval)

print('KNN : ', pred1)
# print('LogisticRegression' + pred2)
# print('SVM' + pred3)
print('DecisionTree : ', + pred4)
print('RandomForest : ', + pred5)
# print('AdaBoost' + pred6)
# print('GradientBoost' + pred7)
# print('LGBM' + pred8)
# print('XGBoost' + pred9)
# print('Voting(hard)' + pred10)
# print('Voting(soft)' + pred11)
# Out:
# KNN :  [[ 1.  8. 20. 33. 33. 44.]
#  [ 2. 12. 14. 27. 34. 44.]
#  [ 1. 10. 18. 31. 37. 45.]
#  ...
#  [ 1.  8. 17. 27. 34. 45.]
#  [ 1. 14. 15. 35. 34. 45.]
#  [ 4. 12. 20. 26. 38. 44.]]
# DecisionTree :  [[ 4.  7. 10. 19. 31. 40.]
#  [ 7. 24. 29. 30. 34. 35.]
#  [ 9. 14. 20. 22. 33. 34.]
#  ...
#  [ 7. 10. 22. 25. 34. 40.]
#  [ 5. 15. 22. 23. 34. 35.]
#  [ 6.  7. 22. 32. 35. 36.]]
# RandomForest :  [[ 1.  8. 20. 31. 34. 45.]
#  [ 1.  8. 20. 31. 34. 45.]
#  [ 1.  8. 20. 31. 34. 45.]
#  ...
#  [ 1. 10. 20. 24. 34. 45.]
#  [ 1.  8. 20. 31. 34. 45.]
#  [ 1.  8. 20. 31. 34. 45.]]

# %%
# 평가용 함수 - 분류
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import mean_squared_error

print(np.sqrt(mean_squared_error(yval, pred1)))
print(np.sqrt(mean_squared_error(yval, pred4)))
print(np.sqrt(mean_squared_error(yval, pred5)))
# Out:
# 8.03940945932505
# 9.47780169862202
# 7.8569194214844105

# %%
# from sklearn.ensemble import RandomForestRegressor

# model = RandomForestRegressor(random_state = 202307,
#                               max_depth = 3,
#                               n_estimators= 5)
# model.fit(Xtr, ytr)

# rpred = model.predict(Xval)
# rpred

# %%
# from sklearn.metrics import mean_squared_error

# print(np.sqrt(mean_squared_error(yval, rpred)))

# %%
# from sklearn.ensemble import RandomForestClassifier

# model2 = RandomForestClassifier(random_state = 202307,
#                               max_depth = 5,
#                               n_estimators= 100)
# model2.fit(Xtr, ytr)

# rpred2 = model2.predict(Xval)
# rpred2

# %%
# from sklearn.metrics import roc_auc_score

# print(roc_auc_score(yval, rpred2))

# %%
# from xgboost import XGBRegressor

# xmodel = XGBRegressor(random_state = 6,
#                       max_depth = 5,
#                       n_estimators = 200)
# xmodel.fit(Xtr, ytr)

# xpred = xmodel.predict(Xval)
# xpred

# %%
# from sklearn.metrics import mean_squared_error

# print(np.sqrt(mean_squared_error(yval, xpred)))

# %%
pred = model1.predict(Xtest)
pred
# Out:
# array([[ 1., 12., 13., 26., 39., 45.],
#        [ 1., 12., 13., 26., 39., 45.],
#        [ 1., 12., 13., 26., 39., 45.],
#        [ 1., 12., 13., 26., 39., 45.],
#        [ 1., 12., 13., 26., 39., 45.],
#        [ 1., 12., 13., 26., 39., 45.]])

# %%
predi = model4.predict(Xtest)
predi
# Out:
# array([[ 1.,  3., 21., 29., 35., 37.],
#        [ 1.,  3., 21., 29., 35., 37.],
#        [ 1.,  3., 21., 29., 35., 37.],
#        [ 1.,  3., 21., 29., 35., 37.],
#        [ 1.,  3., 21., 29., 35., 37.],
#        [ 1.,  3., 21., 29., 35., 37.]])

# %%
predo = model5.predict(Xtest)
predo
# Out:
# array([[11., 12., 18., 21., 31., 38.],
#        [11., 12., 18., 21., 31., 38.],
#        [11., 12., 18., 21., 31., 38.],
#        [11., 12., 18., 21., 31., 38.],
#        [11., 12., 18., 21., 31., 38.],
#        [11., 12., 18., 21., 31., 38.]])
