# %% [markdown]
# <a href="https://colab.research.google.com/github/YonggunJung/colab/blob/main/1094Lotto2%EC%98%88%EC%B8%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/로또/data/lotto2.csv')
df
# Out:
#        1   2   3   4   5   6  보너스     일     이     삼     사     오     육
# 0     11  21  22  30  39  44   31  13.0  14.0  18.0  21.0  34.0  44.0
# 1     13  14  18  21  34  44   16  11.0  16.0  25.0  27.0  35.0  36.0
# 2     11  16  25  27  35  36   37   4.0   7.0  17.0  18.0  38.0  44.0
# 3      4   7  17  18  38  44   36   8.0  12.0  13.0  29.0  33.0  42.0
# 4      8  12  13  29  33  42    5   3.0   7.0  14.0  15.0  22.0  38.0
# ...   ..  ..  ..  ..  ..  ..  ...   ...   ...   ...   ...   ...   ...
# 1088   4  18  31  37  42  43   40  12.0  19.0  21.0  29.0  40.0  45.0
# 1089  12  19  21  29  40  45    1   6.0  20.0  23.0  24.0  28.0  30.0
# 1090   6  20  23  24  28  30   44   7.0  18.0  19.0  26.0  33.0  45.0
# 1091   7  18  19  26  33  45   37  10.0  17.0  22.0  30.0  35.0  43.0
# 1092  10  17  22  30  35  43   44   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1093 rows x 13 columns]

# %%
Xtrain = df.drop(['일', '이', '삼', '사','오', '육'], axis = 1)
Xtrain
# Out:
#        1   2   3   4   5   6  보너스
# 0     11  21  22  30  39  44   31
# 1     13  14  18  21  34  44   16
# 2     11  16  25  27  35  36   37
# 3      4   7  17  18  38  44   36
# 4      8  12  13  29  33  42    5
# ...   ..  ..  ..  ..  ..  ..  ...
# 1088   4  18  31  37  42  43   40
# 1089  12  19  21  29  40  45    1
# 1090   6  20  23  24  28  30   44
# 1091   7  18  19  26  33  45   37
# 1092  10  17  22  30  35  43   44
#
# [1093 rows x 7 columns]

# %%
Xtest = Xtrain.loc[1090]
Xtest
# Out:
# 1       6
# 2      20
# 3      23
# 4      24
# 5      28
# 6      30
# 보너스    44
# Name: 1090, dtype: int64

# %%
Xtrain.drop(1090, inplace = True)
Xtrain
# Out:
#        1   2   3   4   5   6  보너스
# 0     11  21  22  30  39  44   31
# 1     13  14  18  21  34  44   16
# 2     11  16  25  27  35  36   37
# 3      4   7  17  18  38  44   36
# 4      8  12  13  29  33  42    5
# ...   ..  ..  ..  ..  ..  ..  ...
# 1087  10  23  29  33  37  40   16
# 1088   4  18  31  37  42  43   40
# 1089  12  19  21  29  40  45    1
# 1091   7  18  19  26  33  45   37
# 1092  10  17  22  30  35  43   44
#
# [1092 rows x 7 columns]

# %%
ytrain = df.drop(['1', '2', '3', '4','5', '6', '보너스'], axis = 1)
ytrain
# Out:
#          일     이     삼     사     오     육
# 0     13.0  14.0  18.0  21.0  34.0  44.0
# 1     11.0  16.0  25.0  27.0  35.0  36.0
# 2      4.0   7.0  17.0  18.0  38.0  44.0
# 3      8.0  12.0  13.0  29.0  33.0  42.0
# 4      3.0   7.0  14.0  15.0  22.0  38.0
# ...    ...   ...   ...   ...   ...   ...
# 1088  12.0  19.0  21.0  29.0  40.0  45.0
# 1089   6.0  20.0  23.0  24.0  28.0  30.0
# 1090   7.0  18.0  19.0  26.0  33.0  45.0
# 1091  10.0  17.0  22.0  30.0  35.0  43.0
# 1092   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1093 rows x 6 columns]

# %%
ytrain.dropna(inplace = True)
ytrain
# Out:
#          일     이     삼     사     오     육
# 0     13.0  14.0  18.0  21.0  34.0  44.0
# 1     11.0  16.0  25.0  27.0  35.0  36.0
# 2      4.0   7.0  17.0  18.0  38.0  44.0
# 3      8.0  12.0  13.0  29.0  33.0  42.0
# 4      3.0   7.0  14.0  15.0  22.0  38.0
# ...    ...   ...   ...   ...   ...   ...
# 1087   4.0  18.0  31.0  37.0  42.0  43.0
# 1088  12.0  19.0  21.0  29.0  40.0  45.0
# 1089   6.0  20.0  23.0  24.0  28.0  30.0
# 1090   7.0  18.0  19.0  26.0  33.0  45.0
# 1091  10.0  17.0  22.0  30.0  35.0  43.0
#
# [1092 rows x 6 columns]

# %%
ytrain =ytrain.astype(int)
ytrain
# Out:
#        일   이   삼   사   오   육
# 0     13  14  18  21  34  44
# 1     11  16  25  27  35  36
# 2      4   7  17  18  38  44
# 3      8  12  13  29  33  42
# 4      3   7  14  15  22  38
# ...   ..  ..  ..  ..  ..  ..
# 1087   4  18  31  37  42  43
# 1088  12  19  21  29  40  45
# 1089   6  20  23  24  28  30
# 1090   7  18  19  26  33  45
# 1091  10  17  22  30  35  43
#
# [1092 rows x 6 columns]

# %%
from pandas import get_dummies

Xtrain = pd.get_dummies(Xtrain)
Xtest = pd.get_dummies(Xtest)
Xtest
# Out:
#      6   20  23  24  28  30  44
# 1     1   0   0   0   0   0   0
# 2     0   1   0   0   0   0   0
# 3     0   0   1   0   0   0   0
# 4     0   0   0   1   0   0   0
# 5     0   0   0   0   1   0   0
# 6     0   0   0   0   0   1   0
# 보너스   0   0   0   0   0   0   1

# %%
from sklearn.model_selection import train_test_split

Xtr, Xval, ytr, yval = train_test_split(Xtrain, ytrain,
                                        test_size = 0.1,
                                        random_state = 202309)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedGroupKFold
kfold = KFold(n_splits = 10, shuffle = True, random_state = 202309)

# %%
# !pip install KNN
# !pip install SVC
# !pip install decisiontree
# !pip install voting
# Out:
# Collecting KNN
#   Downloading KNN-1.0.0.tar.gz (2.4 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: KNN
#   Building wheel for KNN (setup.py) ... done
#   Created wheel for KNN: filename=KNN-1.0.0-py3-none-any.whl size=3112 sha256=029bbd5362437bdbc292aa8e252ef3defbfa8f4fb19eb777fba086fbfeaa4a84
#   Stored in directory: /root/.cache/pip/wheels/db/f0/9c/9da3fdf7ad3d19587a688434d71dbf38ced30bde9fb2975ff7
# Successfully built KNN
# Installing collected packages: KNN
# Successfully installed KNN-1.0.0
# Collecting SVC
#   Downloading SVC-0.1.tar.gz (1.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: xlrd>=0.9.3 in /usr/local/lib/python3.10/dist-packages (from SVC) (2.0.1)
# Building wheels for collected packages: SVC
#   Building wheel for SVC (setup.py) ... done
#   Created wheel for SVC: filename=SVC-0.1-py3-none-any.whl size=1870 sha256=d37c512b0cb216ab0de16e00f69deb2c654f94ff8549087d7faa0756079c874d
#   Stored in directory: /root/.cache/pip/wheels/88/51/46/316b33cfa9e39d0749762daa17b6a8646e3050079185747370
# Successfully built SVC
# Installing collected packages: SVC
# Successfully installed SVC-0.1
# Collecting decisiontree
#   Downloading DecisionTree-3.4.3.tar.gz (335 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 335.3/335.3 kB 5.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: decisiontree
#   Building wheel for decisiontree (setup.py) ... done
#   Created wheel for decisiontree: filename=DecisionTree-3.4.3-py3-none-any.whl size=81844 sha256=03ba9aaec292d6ebcb34c14caa6acb3666ae431068ee96b5cb644b671eba8c66
#   Stored in directory: /root/.cache/pip/wheels/59/d4/29/d88ed8e92d4c96a49d195c034b7f0e7ce74b10531fbfd98555
# Successfully built decisiontree
# Installing collected packages: decisiontree
# Successfully installed decisiontree-3.4.3
# Collecting voting
#   Downloading voting-0.1.3-py2.py3-none-any.whl (8.0 kB)
# Installing collected packages: voting
# Successfully installed voting-0.1.3

# %%
# 머신러닝 알고리즘 분류
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import VotingClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

model1 = KNeighborsClassifier(n_neighbors = 300,
                              leaf_size = 7)
model2 = LogisticRegression(random_state = 202309)
model3 = SVC(random_state = 202309, probability = True)
model4 = DecisionTreeClassifier(random_state = 202309,
                                max_depth = 50)
model5 = RandomForestClassifier(random_state = 202309,
                                max_depth = 2,
                                n_estimators= 60)
model6 = AdaBoostClassifier(random_state = 202309)
model7 = GradientBoostingClassifier(random_state = 202309)
model8 = LGBMClassifier(random_state = 202309)
model9 = XGBClassifier(random_state = 202309, silent = True, verbosity = 0)

# %%
model1.fit(Xtr, ytr)
# model2.fit(Xtr, ytr)
# model3.fit(Xtr, ytr)
model4.fit(Xtr, ytr)
model5.fit(Xtr, ytr)
# model6.fit(Xtr, ytr)
# model7.fit(Xtr, ytr)
# model8.fit(Xtr, ytr)
# model9.fit(Xtr, ytr)
# model10.fit(Xtr, ytr)
# model11.fit(Xtr, ytr)

pred1 = model1.predict(Xval)
# pred2 = model2.predict(Xval)
# pred3 = model3.predict(Xval)
pred4 = model4.predict(Xval)
pred5 = model5.predict(Xval)
# pred6 = model6.predict(Xval)
# pred7 = model7.predict(Xval)
# pred8 = model8.predict(Xval)
# pred9 = model9.predict(Xval)
# pred10 = model10.predict(Xval)
# pred11 = model11.predict(Xval)

print('KNN : ', pred1)
# print('LogisticRegression' + pred2)
# print('SVM' + pred3)
print('DecisionTree : ', + pred4)
print('RandomForest : ', + pred5)
# print('AdaBoost' + pred6)
# print('GradientBoost' + pred7)
# print('LGBM' + pred8)
# print('XGBoost' + pred9)
# print('Voting(hard)' + pred10)
# print('Voting(soft)' + pred11)
# Out:
# KNN :  [[ 1  7 16 26 33 44]
#  [ 1 10 13 26 39 45]
#  [ 1 14 19 30 34 43]
#  [ 1 11 16 23 34 45]
#  [ 1 14 20 30 34 43]
#  [ 1  8 19 31 34 44]
#  [ 1 11 11 30 34 43]
#  [ 1 10 18 26 38 45]
#  [ 2  7 13 27 38 45]
#  [ 1  8 13 23 34 43]
#  [ 2  7 20 27 34 45]
#  [ 2  7 13 27 34 45]
#  [ 1  8 13 23 34 44]
#  [ 1  8 16 23 33 45]
#  [ 2  7 18 27 38 45]
#  [ 1  8 16 24 33 45]
#  [ 1  8 19 31 34 43]
#  [ 2  9 13 27 39 43]
#  [ 1  8 19 31 34 45]
#  [ 2 10 20 27 34 45]
#  [ 2  7 18 27 32 45]
#  [ 1  9 15 33 34 45]
#  [ 1  8 18 31 33 45]
#  [ 1  8 20 30 34 45]
#  [ 1  9 15 27 38 45]
#  [ 2 10 18 27 34 45]
#  [ 1  8 18 23 34 43]
#  [ 1  8 19 31 34 45]
#  [ 1  8 18 31 37 45]
#  [ 2 10 20 27 39 45]
#  [ 1  8 20 28 34 43]
#  [ 1  8 19 31 34 45]
#  [ 1 14 20 30 34 45]
#  [ 1  8 16 31 34 45]
#  [ 1 12 18 21 34 45]
#  [ 1 14 20 30 34 43]
#  [ 2  7 20 27 38 45]
#  [ 1 11 13 23 38 45]
#  [ 2 10 13 27 34 45]
#  [ 1 10 20 27 38 45]
#  [ 1 10 20 30 39 45]
#  [ 2 10 20 30 34 45]
#  [ 1  8 18 30 34 45]
#  [ 2  8 20 30 34 45]
#  [ 4 10 18 26 38 45]
#  [ 1 10 19 30 39 45]
34 45]
#  [ 1 10 18 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 12 18 21 28 45]
#  [ 1 10 20 26 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  8 19 23 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 12 19 23 38 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 26 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 18 26 27 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 19 30 38 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 24 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  8 19 23 38 44]
#  [ 1 10 20 24 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 18 19 33 36 44]
#  [ 1 10 19 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 18 26 34 45]
#  [ 1 10 13 26 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  8 20 27 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 18 26 38 45]
#  [ 1  8 20 23 39 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 26 34 45]
#  [ 1 10 18 26 38 45]
#  [ 1 10 19 31 39 45]
#  [ 1 10 13 31 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  8 19 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1 10 13 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 24 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 27 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 11 20 21 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  7 16 24 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  7 19 31 36 43]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  8 19 23 39 45]
#  [ 1 10 20 24 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 20 24 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 13 31 34 45]
#  [ 1 10 20 26 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 18 26 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 18 26 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  8 20 27 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 18 26 38 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]]

# %%
# 평가용 함수 - 분류
from sklearn.metrics import mean_squared_error

print(np.sqrt(mean_squared_error(yval, pred1)))
print(np.sqrt(mean_squared_error(yval, pred4)))
print(np.sqrt(mean_squared_error(yval, pred5)))
# Out:
# 7.99080911441578
# 9.573084110877716
# 7.903777386142462

# %%
# from sklearn.ensemble import RandomForestRegressor

# model = RandomForestRegressor(random_state = 202307,
#                               max_depth = 3,
#                               n_estimators= 5)
# model.fit(Xtr, ytr)

# rpred = model.predict(Xval)
# rpred

# %%
# from sklearn.metrics import mean_squared_error

# print(np.sqrt(mean_squared_error(yval, rpred)))

# %%
# from sklearn.ensemble import RandomForestClassifier

# model2 = RandomForestClassifier(random_state = 202307,
#                               max_depth = 5,
#                               n_estimators= 100)
# model2.fit(Xtr, ytr)

# rpred2 = model2.predict(Xval)
# rpred2

# %%
# from sklearn.metrics import roc_auc_score

# print(roc_auc_score(yval, rpred2))

# %%
pred = model1.predict(Xtest)
pred
# Out:
# array([[ 1, 11, 13, 26, 38, 45],
#        [ 1, 11, 13, 26, 38, 45],
#        [ 1, 11, 13, 26, 38, 45],
#        [ 1, 11, 13, 26, 38, 45],
#        [ 1, 11, 13, 26, 38, 45],
#        [ 1, 11, 13, 26, 38, 45],
#        [ 1, 10, 13, 26, 38, 45]])

# %%
from sklearn.neighbors import KNeighborsClassifier

model11 = KNeighborsClassifier(n_neighbors = 300,
                              leaf_size = 7)

model11.fit(Xtrain, ytrain)

kpred = model11.predict(Xtest)
kpred
# Out:
# array([[ 4, 11, 13, 26, 38, 45],
#        [ 4, 11, 13, 26, 38, 45],
#        [ 4, 11, 13, 26, 38, 45],
#        [ 4, 11, 13, 26, 38, 45],
#        [ 1, 11, 13, 26, 38, 45],
#        [ 1, 11, 13, 26, 38, 45],
#        [ 4, 11, 13, 26, 38, 45]])

# %%
predi = model4.predict(Xtest)
predi
# Out:
# array([[10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41]])

# %%
from sklearn.tree import DecisionTreeClassifier

model44 = DecisionTreeClassifier(random_state = 202311,
                                max_depth = 50)
model44.fit(Xtrain, ytrain)

dpred = model44.predict(Xtest)
dpred
# Out:
# array([[11, 12, 18, 21, 31, 38],
#        [11, 12, 18, 21, 31, 38],
#        [11, 12, 18, 21, 31, 38],
#        [11, 12, 18, 21, 31, 38],
#        [11, 12, 18, 21, 31, 38],
#        [11, 12, 18, 21, 31, 38],
#        [11, 12, 18, 21, 31, 38]])

# %%
predo = model5.predict(Xtest)
predo
# Out:
# array([[ 4, 12, 18, 21, 31, 33],
#        [ 4, 12, 18, 21, 31, 33],
#        [ 4, 12, 18, 21, 31, 33],
#        [ 4, 12, 18, 21, 31, 33],
#        [ 4, 12, 18, 21, 31, 33],
#        [ 4, 12, 18, 21, 31, 33],
#        [ 4, 12, 18, 21, 31, 33]])

# %%
from sklearn.ensemble import RandomForestRegressor

model55 = RandomForestClassifier(random_state = 202311,
                                max_depth = 2,
                                n_estimators= 60)
model55.fit(Xtrain, ytrain)

rpred = model55.predict(Xtest)
rpred
# Out:
# array([[ 4, 12, 18, 22, 28, 33],
#        [ 4, 12, 18, 22, 28, 33],
#        [ 4, 12, 18, 22, 28, 33],
#        [ 4, 12, 18, 22, 28, 33],
#        [ 4, 12, 18, 22, 28, 33],
#        [ 4, 12, 18, 22, 28, 33],
#        [ 4, 12, 18, 22, 28, 33]])
