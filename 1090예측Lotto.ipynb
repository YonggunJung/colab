# %% [markdown]
# <a href="https://colab.research.google.com/github/YonggunJung/colab/blob/main/1090%EC%98%88%EC%B8%A1Lotto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/로또/data/lotto.csv')
df
# Out:
#        1   2   3   4   5   6     일     이     삼     사     오     육
# 0      4   7  17  18  38  44   8.0  12.0  13.0  29.0  33.0  42.0
# 1      8  12  13  29  33  42   3.0   7.0  14.0  15.0  22.0  38.0
# 2      3   7  14  15  22  38  21.0  26.0  27.0  32.0  34.0  42.0
# 3     21  26  27  32  34  42   1.0   9.0  16.0  23.0  24.0  38.0
# 4      1   9  16  23  24  38  13.0  16.0  23.0  31.0  36.0  44.0
# ...   ..  ..  ..  ..  ..  ..   ...   ...   ...   ...   ...   ...
# 1084  10  23  29  33  37  40  11.0  16.0  25.0  27.0  35.0  36.0
# 1085  11  16  25  27  35  36  13.0  14.0  18.0  21.0  34.0  44.0
# 1086  13  14  18  21  34  44  11.0  21.0  22.0  30.0  39.0  44.0
# 1087  11  21  22  30  39  44   4.0  18.0  31.0  37.0  42.0  43.0
# 1088   4  18  31  37  42  43   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1089 rows x 12 columns]

# %%
Xtrain = df.drop(['일', '이', '삼', '사','오', '육'], axis = 1)
Xtrain
# Out:
#        1   2   3   4   5   6
# 0      4   7  17  18  38  44
# 1      8  12  13  29  33  42
# 2      3   7  14  15  22  38
# 3     21  26  27  32  34  42
# 4      1   9  16  23  24  38
# ...   ..  ..  ..  ..  ..  ..
# 1084  10  23  29  33  37  40
# 1085  11  16  25  27  35  36
# 1086  13  14  18  21  34  44
# 1087  11  21  22  30  39  44
# 1088   4  18  31  37  42  43
#
# [1089 rows x 6 columns]

# %%
Xtest = Xtrain.loc[1088]
Xtest
# Out:
# 1     4
# 2    18
# 3    31
# 4    37
# 5    42
# 6    43
# Name: 1088, dtype: int64

# %%
Xtrain.drop(1088, inplace = True)
Xtrain
# Out:
#        1   2   3   4   5   6
# 0      4   7  17  18  38  44
# 1      8  12  13  29  33  42
# 2      3   7  14  15  22  38
# 3     21  26  27  32  34  42
# 4      1   9  16  23  24  38
# ...   ..  ..  ..  ..  ..  ..
# 1083   9  13  21  25  32  42
# 1084  10  23  29  33  37  40
# 1085  11  16  25  27  35  36
# 1086  13  14  18  21  34  44
# 1087  11  21  22  30  39  44
#
# [1088 rows x 6 columns]

# %%
ytrain = df.drop(['1', '2', '3', '4','5', '6'], axis = 1)
ytrain
# Out:
#          일     이     삼     사     오     육
# 0      8.0  12.0  13.0  29.0  33.0  42.0
# 1      3.0   7.0  14.0  15.0  22.0  38.0
# 2     21.0  26.0  27.0  32.0  34.0  42.0
# 3      1.0   9.0  16.0  23.0  24.0  38.0
# 4     13.0  16.0  23.0  31.0  36.0  44.0
# ...    ...   ...   ...   ...   ...   ...
# 1084  11.0  16.0  25.0  27.0  35.0  36.0
# 1085  13.0  14.0  18.0  21.0  34.0  44.0
# 1086  11.0  21.0  22.0  30.0  39.0  44.0
# 1087   4.0  18.0  31.0  37.0  42.0  43.0
# 1088   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1089 rows x 6 columns]

# %%
ytrain.dropna(inplace = True)
ytrain
# Out:
#          일     이     삼     사     오     육
# 0      8.0  12.0  13.0  29.0  33.0  42.0
# 1      3.0   7.0  14.0  15.0  22.0  38.0
# 2     21.0  26.0  27.0  32.0  34.0  42.0
# 3      1.0   9.0  16.0  23.0  24.0  38.0
# 4     13.0  16.0  23.0  31.0  36.0  44.0
# ...    ...   ...   ...   ...   ...   ...
# 1083  10.0  23.0  29.0  33.0  37.0  40.0
# 1084  11.0  16.0  25.0  27.0  35.0  36.0
# 1085  13.0  14.0  18.0  21.0  34.0  44.0
# 1086  11.0  21.0  22.0  30.0  39.0  44.0
# 1087   4.0  18.0  31.0  37.0  42.0  43.0
#
# [1088 rows x 6 columns]

# %%
ytrain =ytrain.astype(int)
ytrain
# Out:
#        일   이   삼   사   오   육
# 0      8  12  13  29  33  42
# 1      3   7  14  15  22  38
# 2     21  26  27  32  34  42
# 3      1   9  16  23  24  38
# 4     13  16  23  31  36  44
# ...   ..  ..  ..  ..  ..  ..
# 1083  10  23  29  33  37  40
# 1084  11  16  25  27  35  36
# 1085  13  14  18  21  34  44
# 1086  11  21  22  30  39  44
# 1087   4  18  31  37  42  43
#
# [1088 rows x 6 columns]

# %%
from pandas import get_dummies

Xtrain = pd.get_dummies(Xtrain)
Xtest = pd.get_dummies(Xtest)
Xtest
# Out:
#    4   18  31  37  42  43
# 1   1   0   0   0   0   0
# 2   0   1   0   0   0   0
# 3   0   0   1   0   0   0
# 4   0   0   0   1   0   0
# 5   0   0   0   0   1   0
# 6   0   0   0   0   0   1

# %%
from sklearn.model_selection import train_test_split

Xtr, Xval, ytr, yval = train_test_split(Xtrain, ytrain,
                                        test_size = 0.1,
                                        random_state = 202309)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedGroupKFold
kfold = KFold(n_splits = 10, shuffle = True, random_state = 202309)

# %%
# !pip install KNN
# !pip install SVC
# !pip install decisiontree
# !pip install voting
# Out:
# Requirement already satisfied: KNN in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: SVC in /usr/local/lib/python3.10/dist-packages (0.1)
# Requirement already satisfied: xlrd>=0.9.3 in /usr/local/lib/python3.10/dist-packages (from SVC) (2.0.1)
# Requirement already satisfied: decisiontree in /usr/local/lib/python3.10/dist-packages (3.4.3)
# Requirement already satisfied: voting in /usr/local/lib/python3.10/dist-packages (0.1.3)

# %%
# 머신러닝 알고리즘 분류
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import VotingClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

model1 = KNeighborsClassifier(n_neighbors = 700)
model2 = LogisticRegression(random_state = 202309)
model3 = SVC(random_state = 202309, probability = True)
model4 = DecisionTreeClassifier(random_state = 202309,
                                max_depth = 50)
model5 = RandomForestClassifier(random_state = 202309,
                                max_depth = 2,
                                n_estimators= 60)
model6 = AdaBoostClassifier(random_state = 202309)
model7 = GradientBoostingClassifier(random_state = 202309)
model8 = LGBMClassifier(random_state = 202309)
model9 = XGBClassifier(random_state = 202309, silent = True, verbosity = 0)

# %%
model1.fit(Xtr, ytr)
# model2.fit(Xtr, ytr)
# model3.fit(Xtr, ytr)
model4.fit(Xtr, ytr)
model5.fit(Xtr, ytr)
# model6.fit(Xtr, ytr)
# model7.fit(Xtr, ytr)
# model8.fit(Xtr, ytr)
# model9.fit(Xtr, ytr)
# model10.fit(Xtr, ytr)
# model11.fit(Xtr, ytr)

pred1 = model1.predict(Xval)
# pred2 = model2.predict(Xval)
# pred3 = model3.predict(Xval)
pred4 = model4.predict(Xval)
pred5 = model5.predict(Xval)
# pred6 = model6.predict(Xval)
# pred7 = model7.predict(Xval)
# pred8 = model8.predict(Xval)
# pred9 = model9.predict(Xval)
# pred10 = model10.predict(Xval)
# pred11 = model11.predict(Xval)

print('KNN : ', pred1)
# print('LogisticRegression' + pred2)
# print('SVM' + pred3)
print('DecisionTree : ', + pred4)
print('RandomForest : ', + pred5)
# print('AdaBoost' + pred6)
# print('GradientBoost' + pred7)
# print('LGBM' + pred8)
# print('XGBoost' + pred9)
# print('Voting(hard)' + pred10)
# print('Voting(soft)' + pred11)
# Out:
# KNN :  [[ 1  8 20 31 34 45]
#  [ 1  8 20 24 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 20 27 34 45]
#  [ 1 11 17 27 34 45]
#  [ 1  8 20 27 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1 10 20 27 34 45]
#  [ 1 10 20 27 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1 11 17 27 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 20 24 34 45]
#  [ 1 10 20 24 39 45]
#  [ 1  7 20 24 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 20 24 34 45]
#  [ 1  8 15 27 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  7 20 27 34 45]
#  [ 1 11 17 27 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  7 20 24 39 45]
#  [ 1  8 20 27 34 45]
#  [ 1  8 20 24 34 45]
#  [ 1 10 17 27 34 45]
#  [ 1  7 15 24 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  7 20 24 39 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 20 24 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 20 27 34 45]
#  [ 1  8 20 27 34 45]
#  [ 1  8 15 31 34 44]
#  [ 1  8 20 27 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 20 27 34 45]
#  [ 1  8 15 27 34 45]
#  [ 1  8 20 27 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1 10 20 24 34 45]
#  [ 1  7 20 24 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 20 27 34 45]
#  [ 1  9 20 27 34 45]
#  [ 1  7 20 24 34 45]
#  [ 1  8 20 24 34 45]
#  [ 1  9 20 24 39 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 20 27 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  9 20 24 34 45]
#  [ 1  7 20 24 34 45]
#  [ 1 10 20 27 39 45]
#  [ 1  7 18 24 34 45]
#  [ 1  8 20 24 34 45]
#  [ 1 10 20 24 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 15 24 34 45]
#  [ 1 11 17 27 34 45]
#  [ 1  8 20 27 34 45]
#  [ 1  8 15 24 34 45]
#  [ 1 10 20 27 34 45]
#  [ 1  8 15 24 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1 10 20 27 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 20 27 34 45]
#  [ 1  8 20 30 34 45]
#  [ 1  8 15 27 34 45]
#  [ 1 11 20 27 39 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 20 24 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 20 27 34 45]
#  [ 1  8 20 27 34 45]
#  [ 1  7 20 24 34 45]
#  [ 1  8 20 27 34 45]
#  [ 1  8 20 27 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 20 24 34 45]
#  [ 1  8 20 24 34 45]
#  [ 1  8 20 24 34 45]
#  [ 1  8 20 27 34 45]
#  [ 1  8 20 24 34 45]
#  [ 1  8 20 24 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1 11 20 27 39 45]
#  [ 1 10 20 27 34 45]
#  [ 1 10 20 24 34 45]
#  [ 1  8 20 24 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  7 20 24 34 45]
#  [ 1  7 20 24 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 20 27 34 45]
#  [ 1  8 15 27 34 45]
#  [ 1  8 20 27 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  7 15 24 34 45]]
# DecisionTree :  [[ 6 13 27 31 32 37]
#  [ 5  8 21 23 27 33]
#  [ 2  4  6 11 17 28]
#  [10 13 25 29 33 35]
#  [ 3 12 33 36 42 45]
#  [ 1  8 24 31 34 44]
#  [ 5  8 22 28 33 42]
#  [ 1  2  6 16 20 33]
#  [ 4 10 12 22 24 33]
#  [ 2  4 21 25 33 36]
#  [ 4  6 10 19 20 44]
#  [ 1 10 13 16 37 43]
#  [ 7 18 22 23 29 44]
#  [ 1  6 20 27 28 41]
#  [ 3 13 15 40 41 44]
#  [ 4 16 25 29 34 35]
#  [21 25 30 32 40 42]
#  [17 25 33 35 38 45]
#  [ 6 31 35 38 39 44]
#  [15 20 23 26 39 44]
#  [10 11 29 38 41 45]
#  [ 3 23 28 34 39 42]
#  [ 1  9 12 23 39 43]
#  [11 30 34 35 42 44]
#  [ 1  3 17 20 31 44]
#  [11 16 29 38 41 44]
#  [ 2 11 19 25 28 32]
#  [ 2 18 25 28 37 39]
#  [ 3 13 18 33 37 45]
#  [ 6 12 19 23 34 42]
#  [14 23 26 31 39 45]
#  [29 31 35 38 40 44]
#  [21 25 33 34 35 36]
#  [14 23 26 31 39 45]
#  [ 5  9 12 30 39 43]
#  [ 8 12 29 31 42 43]
#  [ 2 21 28 38 42 45]
#  [ 5  6 13 14 17 20]
#  [ 5 15 21 23 25 45]
#  [ 1 10 20 32 35 40]
#  [22 23 25 37 38 42]
#  [ 5 22 29 31 34 39]
#  [ 5 22 29 31 34 39]
#  [ 6 10 18 26 37 38]
#  [ 6 11 16 19 21 32]
#  [ 1  2  5 11 18 36]
#  [ 2  4 15 28 31 34]
#  [12 14 24 26 34 45]
#  [ 9 12 15 25 34 36]
#  [ 7 16 31 36 37 38]
#  [ 6 11 16 18 31 43]
#  [ 9 17 19 30 35 42]
#  [ 2 19 25 26 27 43]
#  [ 1 11 16 17 36 40]
#  [ 6  9 10 11 39 41]
#  [ 1  4 16 26 40 41]
#  [13 18 26 31 34 44]
#  [ 3  4  6 10 28 30]
#  [14 21 23 32 40 45]
#  [11 17 28 30 33 35]
#  [ 5  6 13 16 27 28]
#  [ 6  9 10 11 39 41]
#  [ 1  9 12 26 35 38]
#  [ 5 18 30 41 43 45]
#  [ 1 11 17 27 35 39]
#  [ 4 18 31 37 42 43]
#  [ 8 14 17 27 36 45]
#  [ 5 11 13 19 31 36]
#  [12 13 17 22 25 33]
#  [16 23 27 34 42 45]
#  [ 2 16 17 32 39 45]
#  [ 2 17 19 24 37 41]
#  [ 1  3 30 33 36 39]
#  [ 7 22 29 33 34 35]
#  [ 7 10 19 22 35 40]
#  [ 4 11 28 39 42 45]
#  [13 15 18 24 27 41]
#  [ 2  8 33 35 37 41]
#  [ 6 30 38 39 40 43]
#  [11 16 18 19 24 39]
#  [ 7 10 22 25 34 40]
#  [16 17 34 36 42 45]
#  [ 1  4 10 14 15 35]
#  [ 6  8 14 21 30 37]
#  [ 1  4 13 29 38 39]
#  [12 18 24 26 39 40]
#  [ 1  9 12 26 35 38]
#  [ 1  3 24 27 39 45]
#  [ 3 11 21 30 38 45]
#  [ 7 14 17 20 35 39]
#  [ 2 12 30 31 39 43]
#  [ 5 21 27 34 44 45]
#  [ 5  8 21 23 27 33]
#  [ 4  5  9 11 23 38]
#  [ 8 13 15 28 37 43]
#  [14 25 31 34 40 44]
#  [16 19 24 33 42 44]
#  [ 6 13 20 27 28 40]
#  [ 4  9 10 29 31 34]
#  [13 19 20 32 38 42]
#  [14 23 30 32 34 38]
#  [ 1  7 16 18 34 38]
#  [14 27 30 31 40 42]
#  [ 2  6 11 13 22 37]
#  [ 1 17 27 28 29 40]
#  [ 5 12 14 32 34 42]
#  [12 23 26 30 36 43]
#  [ 8 12 29 31 42 43]
#  [ 2  6 17 18 21 26]]
# RandomForest :  [[ 1 12 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 11 20 31 34 45]
#  [ 1 10 18 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 13 33 39 45]
#  [ 1 12 18 21 28 45]
#  [ 4 10 12 22 28 45]
#  [ 1  8 20 29 39 45]
#  [ 1 10 20 26 34 45]
#  [ 1 10 20 26 39 45]
#  [ 1  7 20 31 34 45]
#  [ 1 10 19 26 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  7 20 27 34 45]
#  [ 1 10 20 26 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1 10 17 31 39 45]
#  [ 1 10 20 31 34 45]
#  [ 1  7 13 33 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  9 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1 10 17 26 39 45]
#  [ 1 10 20 31 34 45]
#  [ 1 12 13 33 34 45]
#  [ 1  7 18 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 18 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 3 12 13 19 39 43]
#  [ 1  7 18 33 34 45]
#  [ 1 12 18 27 39 45]
#  [ 1 10 18 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 18 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1 11 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 18 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1 11 20 31 34 45]
#  [ 1 10 19 26 39 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 11 19 26 40 44]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 18 26 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1 10 17 26 39 45]
#  [ 1 10 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1 10 17 21 39 45]
#  [ 1  7 19 22 35 45]
#  [ 1 10 20 31 34 45]
#  [ 1 11 15 30 39 45]
#  [ 1  7 20 31 34 45]
#  [ 1 11 20 26 39 45]
#  [ 1  7 20 31 34 45]
#  [ 1 10 18 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  7 18 31 39 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 18 31 34 45]
#  [ 1 11 19 33 39 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 13 33 34 45]
#  [ 1 10 20 31 34 45]]

# %%
# 평가용 함수 - 분류
from sklearn.metrics import mean_squared_error

print(np.sqrt(mean_squared_error(yval, pred1)))
print(np.sqrt(mean_squared_error(yval, pred4)))
print(np.sqrt(mean_squared_error(yval, pred5)))
# Out:
# 7.773455184445791
# 8.858555532151275
# 7.845507489486203

# %%
# from sklearn.ensemble import RandomForestRegressor

# model = RandomForestRegressor(random_state = 202307,
#                               max_depth = 3,
#                               n_estimators= 5)
# model.fit(Xtr, ytr)

# rpred = model.predict(Xval)
# rpred

# %%
# from sklearn.metrics import mean_squared_error

# print(np.sqrt(mean_squared_error(yval, rpred)))

# %%
# from sklearn.ensemble import RandomForestClassifier

# model2 = RandomForestClassifier(random_state = 202307,
#                               max_depth = 5,
#                               n_estimators= 100)
# model2.fit(Xtr, ytr)

# rpred2 = model2.predict(Xval)
# rpred2

# %%
# from sklearn.metrics import roc_auc_score

# print(roc_auc_score(yval, rpred2))

# %%
pred = model1.predict(Xtest)
pred
# Out:
# array([[ 1, 12, 18, 16, 39, 44],
#        [ 1, 12, 18, 16, 39, 44],
#        [ 1, 12, 18, 16, 39, 44],
#        [ 1, 12, 18, 16, 39, 44],
#        [ 1, 12, 18, 26, 39, 44],
#        [ 1, 12, 18, 16, 39, 44]])

# %%
predi = model4.predict(Xtest)
predi
# Out:
# array([[10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41]])

# %%
predo = model5.predict(Xtest)
predo
# Out:
# array([[ 1, 17, 27, 33, 39, 43],
#        [ 1, 17, 27, 33, 39, 43],
#        [ 1, 17, 27, 33, 39, 43],
#        [ 1, 17, 27, 33, 39, 43],
#        [ 1, 17, 27, 33, 39, 43],
#        [ 1, 17, 27, 33, 39, 43]])
