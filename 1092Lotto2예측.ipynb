# %% [markdown]
# <a href="https://colab.research.google.com/github/YonggunJung/colab/blob/main/1092Lotto2%EC%98%88%EC%B8%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/로또/data/lotto2.csv')
df
# Out:
#        1   2   3   4   5   6  보너스     일     이     삼     사     오     육
# 0     11  21  22  30  39  44   31  13.0  14.0  18.0  21.0  34.0  44.0
# 1     13  14  18  21  34  44   16  11.0  16.0  25.0  27.0  35.0  36.0
# 2     11  16  25  27  35  36   37   4.0   7.0  17.0  18.0  38.0  44.0
# 3      4   7  17  18  38  44   36   8.0  12.0  13.0  29.0  33.0  42.0
# 4      8  12  13  29  33  42    5   3.0   7.0  14.0  15.0  22.0  38.0
# ...   ..  ..  ..  ..  ..  ..  ...   ...   ...   ...   ...   ...   ...
# 1086   9  13  21  25  32  42    2  10.0  23.0  29.0  33.0  37.0  40.0
# 1087  10  23  29  33  37  40   16   4.0  18.0  31.0  37.0  42.0  43.0
# 1088   4  18  31  37  42  43   40  12.0  19.0  21.0  29.0  40.0  45.0
# 1089  12  19  21  29  40  45    1   6.0  20.0  23.0  24.0  28.0  30.0
# 1090   6  20  23  24  28  30   44   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1091 rows x 13 columns]

# %%
Xtrain = df.drop(['일', '이', '삼', '사','오', '육'], axis = 1)
Xtrain
# Out:
#        1   2   3   4   5   6  보너스
# 0     11  21  22  30  39  44   31
# 1     13  14  18  21  34  44   16
# 2     11  16  25  27  35  36   37
# 3      4   7  17  18  38  44   36
# 4      8  12  13  29  33  42    5
# ...   ..  ..  ..  ..  ..  ..  ...
# 1086   9  13  21  25  32  42    2
# 1087  10  23  29  33  37  40   16
# 1088   4  18  31  37  42  43   40
# 1089  12  19  21  29  40  45    1
# 1090   6  20  23  24  28  30   44
#
# [1091 rows x 7 columns]

# %%
Xtest = Xtrain.loc[1089]
Xtest
# Out:
# 1      12
# 2      19
# 3      21
# 4      29
# 5      40
# 6      45
# 보너스     1
# Name: 1089, dtype: int64

# %%
Xtrain.drop(1089, inplace = True)
Xtrain
# Out:
#        1   2   3   4   5   6  보너스
# 0     11  21  22  30  39  44   31
# 1     13  14  18  21  34  44   16
# 2     11  16  25  27  35  36   37
# 3      4   7  17  18  38  44   36
# 4      8  12  13  29  33  42    5
# ...   ..  ..  ..  ..  ..  ..  ...
# 1085  11  16  19  21  27  31   30
# 1086   9  13  21  25  32  42    2
# 1087  10  23  29  33  37  40   16
# 1088   4  18  31  37  42  43   40
# 1090   6  20  23  24  28  30   44
#
# [1090 rows x 7 columns]

# %%
ytrain = df.drop(['1', '2', '3', '4','5', '6', '보너스'], axis = 1)
ytrain
# Out:
#          일     이     삼     사     오     육
# 0     13.0  14.0  18.0  21.0  34.0  44.0
# 1     11.0  16.0  25.0  27.0  35.0  36.0
# 2      4.0   7.0  17.0  18.0  38.0  44.0
# 3      8.0  12.0  13.0  29.0  33.0  42.0
# 4      3.0   7.0  14.0  15.0  22.0  38.0
# ...    ...   ...   ...   ...   ...   ...
# 1086  10.0  23.0  29.0  33.0  37.0  40.0
# 1087   4.0  18.0  31.0  37.0  42.0  43.0
# 1088  12.0  19.0  21.0  29.0  40.0  45.0
# 1089   6.0  20.0  23.0  24.0  28.0  30.0
# 1090   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1091 rows x 6 columns]

# %%
ytrain.dropna(inplace = True)
ytrain
# Out:
#          일     이     삼     사     오     육
# 0     13.0  14.0  18.0  21.0  34.0  44.0
# 1     11.0  16.0  25.0  27.0  35.0  36.0
# 2      4.0   7.0  17.0  18.0  38.0  44.0
# 3      8.0  12.0  13.0  29.0  33.0  42.0
# 4      3.0   7.0  14.0  15.0  22.0  38.0
# ...    ...   ...   ...   ...   ...   ...
# 1085   9.0  13.0  21.0  25.0  32.0  42.0
# 1086  10.0  23.0  29.0  33.0  37.0  40.0
# 1087   4.0  18.0  31.0  37.0  42.0  43.0
# 1088  12.0  19.0  21.0  29.0  40.0  45.0
# 1089   6.0  20.0  23.0  24.0  28.0  30.0
#
# [1090 rows x 6 columns]

# %%
ytrain =ytrain.astype(int)
ytrain
# Out:
#        일   이   삼   사   오   육
# 0     13  14  18  21  34  44
# 1     11  16  25  27  35  36
# 2      4   7  17  18  38  44
# 3      8  12  13  29  33  42
# 4      3   7  14  15  22  38
# ...   ..  ..  ..  ..  ..  ..
# 1085   9  13  21  25  32  42
# 1086  10  23  29  33  37  40
# 1087   4  18  31  37  42  43
# 1088  12  19  21  29  40  45
# 1089   6  20  23  24  28  30
#
# [1090 rows x 6 columns]

# %%
from pandas import get_dummies

Xtrain = pd.get_dummies(Xtrain)
Xtest = pd.get_dummies(Xtest)
Xtest
# Out:
#      1   12  19  21  29  40  45
# 1     0   1   0   0   0   0   0
# 2     0   0   1   0   0   0   0
# 3     0   0   0   1   0   0   0
# 4     0   0   0   0   1   0   0
# 5     0   0   0   0   0   1   0
# 6     0   0   0   0   0   0   1
# 보너스   1   0   0   0   0   0   0

# %%
from sklearn.model_selection import train_test_split

Xtr, Xval, ytr, yval = train_test_split(Xtrain, ytrain,
                                        test_size = 0.1,
                                        random_state = 202309)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedGroupKFold
kfold = KFold(n_splits = 10, shuffle = True, random_state = 202309)

# %%
# !pip install KNN
# !pip install SVC
# !pip install decisiontree
# !pip install voting
# Out:
# Collecting KNN
#   Downloading KNN-1.0.0.tar.gz (2.4 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: KNN
#   Building wheel for KNN (setup.py) ... done
#   Created wheel for KNN: filename=KNN-1.0.0-py3-none-any.whl size=3111 sha256=38907fc8efb144cfed98f42b015ddd5e74422a8b42142dc6e26af5ac8bd673c2
#   Stored in directory: /root/.cache/pip/wheels/db/f0/9c/9da3fdf7ad3d19587a688434d71dbf38ced30bde9fb2975ff7
# Successfully built KNN
# Installing collected packages: KNN
# Successfully installed KNN-1.0.0
# Collecting SVC
#   Downloading SVC-0.1.tar.gz (1.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: xlrd>=0.9.3 in /usr/local/lib/python3.10/dist-packages (from SVC) (2.0.1)
# Building wheels for collected packages: SVC
#   Building wheel for SVC (setup.py) ... done
#   Created wheel for SVC: filename=SVC-0.1-py3-none-any.whl size=1870 sha256=141233e6cd0026c589132bca95758035392d4e426af180d3c1c979ef7f809ab6
#   Stored in directory: /root/.cache/pip/wheels/88/51/46/316b33cfa9e39d0749762daa17b6a8646e3050079185747370
# Successfully built SVC
# Installing collected packages: SVC
# Successfully installed SVC-0.1
# Collecting decisiontree
#   Downloading DecisionTree-3.4.3.tar.gz (335 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 335.3/335.3 kB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: decisiontree
#   Building wheel for decisiontree (setup.py) ... done
#   Created wheel for decisiontree: filename=DecisionTree-3.4.3-py3-none-any.whl size=81843 sha256=b2349ffac02d8b0c730053821cf56b6f467c0cb4ba9906774023f9daebaacce5
#   Stored in directory: /root/.cache/pip/wheels/59/d4/29/d88ed8e92d4c96a49d195c034b7f0e7ce74b10531fbfd98555
# Successfully built decisiontree
# Installing collected packages: decisiontree
# Successfully installed decisiontree-3.4.3
# Collecting voting
#   Downloading voting-0.1.3-py2.py3-none-any.whl (8.0 kB)
# Installing collected packages: voting
# Successfully installed voting-0.1.3

# %%
# 머신러닝 알고리즘 분류
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import VotingClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

model1 = KNeighborsClassifier(n_neighbors = 700)
model2 = LogisticRegression(random_state = 202309)
model3 = SVC(random_state = 202309, probability = True)
model4 = DecisionTreeClassifier(random_state = 202309,
                                max_depth = 50)
model5 = RandomForestClassifier(random_state = 202309,
                                max_depth = 2,
                                n_estimators= 60)
model6 = AdaBoostClassifier(random_state = 202309)
model7 = GradientBoostingClassifier(random_state = 202309)
model8 = LGBMClassifier(random_state = 202309)
model9 = XGBClassifier(random_state = 202309, silent = True, verbosity = 0)

# %%
model1.fit(Xtr, ytr)
# model2.fit(Xtr, ytr)
# model3.fit(Xtr, ytr)
model4.fit(Xtr, ytr)
model5.fit(Xtr, ytr)
# model6.fit(Xtr, ytr)
# model7.fit(Xtr, ytr)
# model8.fit(Xtr, ytr)
# model9.fit(Xtr, ytr)
# model10.fit(Xtr, ytr)
# model11.fit(Xtr, ytr)

pred1 = model1.predict(Xval)
# pred2 = model2.predict(Xval)
# pred3 = model3.predict(Xval)
pred4 = model4.predict(Xval)
pred5 = model5.predict(Xval)
# pred6 = model6.predict(Xval)
# pred7 = model7.predict(Xval)
# pred8 = model8.predict(Xval)
# pred9 = model9.predict(Xval)
# pred10 = model10.predict(Xval)
# pred11 = model11.predict(Xval)

print('KNN : ', pred1)
# print('LogisticRegression' + pred2)
# print('SVM' + pred3)
print('DecisionTree : ', + pred4)
print('RandomForest : ', + pred5)
# print('AdaBoost' + pred6)
# print('GradientBoost' + pred7)
# print('LGBM' + pred8)
# print('XGBoost' + pred9)
# print('Voting(hard)' + pred10)
# print('Voting(soft)' + pred11)
# Out:
# KNN :  [[ 1  8 20 31 34 45]
#  [ 1 10 20 26 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  8 19 31 34 45]
#  [ 1  8 16 33 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1 10 18 27 34 45]
#  [ 1 10 20 24 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1 10 20 26 34 45]
#  [ 1 10 20 26 34 45]
#  [ 1  8 19 31 34 45]
#  [ 1  7 16 31 34 45]
#  [ 1 10 20 27 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  8 19 31 34 45]
#  [ 1  7 16 31 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 26 34 45]
#  [ 1  7 13 27 34 45]
#  [ 1  7 19 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  8 16 33 34 45]
#  [ 1 10 20 26 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 19 31 34 45]
#  [ 1  7 20 26 34 45]
#  [ 1 10 20 26 34 45]
#  [ 1  8 19 31 34 45]
#  [ 1  8 19 31 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 16 31 34 45]
#  [ 1  8 19 31 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  7 20 26 34 45]
#  [ 1  8 19 31 34 45]
#  [ 1 10 20 26 34 45]
#  [ 1 10 20 26 34 45]
#  [ 1  8 20 23 34 45]
#  [ 1  8 20 23 34 45]
#  [ 1  8 16 31 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1 10 20 27 34 45]
#  [ 1  7 13 31 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1 10 20 26 34 45]
#  [ 1  8 19 33 34 45]
#  [ 1  8 20 23 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1 10 20 26 34 45]
#  [ 1  7 20 27 34 45]
#  [ 1  8 13 27 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 16 33 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 18 30 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  8 13 33 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 16 31 34 45]
#  [ 1  7 13 27 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 26 34 45]
#  [ 1 10 20 26 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1 10 20 26 34 45]
#  [ 1  8 13 31 34 45]
#  [ 1 10 20 26 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 13 31 34 45]
#  [ 1 10 20 26 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 13 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 26 34 45]
#  [ 1  7 19 31 34 45]
#  [ 1  8 19 31 34 45]
#  [ 1 10 20 26 34 45]
#  [ 1  8 20 27 34 45]
#  [ 1 10 20 26 34 45]
#  [ 1  8 19 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  8 16 33 34 45]
#  [ 1  8 13 31 34 45]
#  [ 1  8 16 31 34 45]
#  [ 1  8 19 31 34 45]
#  [ 1  7 16 31 34 45]
#  [ 1  8 18 31 34 45]
#  [ 1 10 20 26 34 45]
#  [ 1  7 16 33 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1 10 20 24 34 45]
#  [ 1 10 20 26 34 45]
#  [ 1  8 16 26 34 45]
#  [ 1 10 20 27 34 45]
#  [ 1 10 20 26 34 45]
#  [ 1  8 20 27 34 45]
#  [ 1  7 18 27 34 45]
#  [ 1 10 20 27 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  8 19 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 24 34 45]
#  [ 1  8 19 33 34 45]]
# DecisionTree :  [[14 15 18 21 26 36]
#  [ 5 25 27 29 34 36]
#  [17 21 31 37 40 44]
#  [12 29 32 33 39 40]
#  [ 5 17 26 27 35 38]
#  [19 20 23 24 43 44]
#  [ 4 18 23 30 34 41]
#  [ 6 12 17 18 31 32]
#  [ 2  3  7 17 22 24]
#  [ 6 14 22 28 35 39]
#  [ 5 13 14 20 24 25]
#  [ 8 14 23 36 38 39]
#  [ 7  8 13 15 33 45]
#  [ 3  4  9 11 22 42]
#  [20 22 26 33 36 37]
#  [16 27 35 37 43 45]
#  [ 2  9 16 25 26 40]
#  [ 5 16 21 26 34 42]
#  [ 3  6 17 23 37 39]
#  [14 15 16 19 25 43]
#  [18 22 25 31 38 45]
#  [ 5  9 14 26 30 43]
#  [ 1  9 12 26 35 38]
#  [12 19 21 29 40 45]
#  [ 4  6 13 17 28 40]
#  [10 24 26 29 37 38]
#  [ 4  8  9 16 17 19]
#  [14 15 25 28 29 30]
#  [ 1  7 11 23 37 42]
#  [ 2 15 20 21 29 34]
#  [ 1  4 10 17 31 42]
#  [ 4  9 14 26 31 44]
#  [ 8 13 20 22 23 36]
#  [ 1  2 16 22 38 39]
#  [ 8 15 17 19 43 44]
#  [ 7  8 13 15 33 45]
#  [ 4  5 31 35 43 45]
#  [10 34 38 40 42 43]
#  [ 8 11 15 16 17 37]
#  [ 3  8  9 27 29 40]
#  [ 7 17 20 32 44 45]
#  [ 6  7 18 19 30 38]
#  [ 4 12 22 24 33 41]
#  [ 4  5  6 25 26 43]
#  [ 5 18 20 36 42 43]
#  [ 5 11 12 29 33 44]
#  [ 2  7 12 15 21 34]
#  [ 1  2 10 25 26 44]
#  [ 1  5 13 34 39 40]
#  [ 2 13 25 28 29 36]
#  [ 1 11 13 24 28 40]
#  [ 7 17 19 23 24 45]
#  [ 6  9 16 23 24 32]
#  [ 7 22 29 33 34 35]
#  [ 8 11 16 19 21 25]
#  [ 6 10 18 31 32 34]
#  [ 2  8 25 36 39 42]
#  [ 3  7  9 33 36 37]
#  [ 3  4  6 10 28 30]
#  [ 5 13 14 22 44 45]
#  [ 4  5 14 35 42 45]
#  [10 13 25 29 33 35]
#  [ 8 10 18 30 32 34]
#  [ 5  8 22 28 33 42]
#  [11 16 19 21 27 31]
#  [ 5  9 17 25 39 43]
#  [ 2  3 11 26 37 43]
#  [11 17 21 26 36 45]
#  [ 5  6 24 25 32 37]
#  [ 7 13 30 39 41 45]
#  [ 1  2 10 25 26 44]
#  [10 13 25 29 33 35]
#  [ 1  6 13 37 38 40]
#  [ 2 25 28 30 33 45]
#  [ 1  5  6 14 20 39]
#  [ 8 24 28 35 38 40]
#  [12 15 19 22 28 34]
#  [ 6 14 16 21 27 37]
#  [ 7  9 24 29 34 38]
#  [14 15 26 27 40 42]
#  [ 5  6  9 11 15 37]
#  [ 7 18 19 27 29 42]
#  [ 4 10 20 32 38 44]
#  [ 6 12 20 26 29 38]
#  [ 1  4 13 29 38 39]
#  [24 25 33 34 38 39]
#  [ 4 18 23 30 34 41]
#  [ 9 18 29 32 38 43]
#  [ 9 12 24 25 29 31]
#  [ 1  5  9 21 27 35]
#  [ 3  5 12 22 26 31]
#  [ 1  3  8 24 27 35]
#  [ 7  9 24 29 34 38]
#  [17 18 31 32 33 34]
#  [ 3  8 17 23 38 45]
#  [11 15 24 39 41 44]
#  [ 4  5  6 12 25 37]
#  [12 19 20 25 41 45]
#  [ 3  5  7 14 26 34]
#  [ 8 17 21 24 27 31]
#  [ 8 13 19 27 40 45]
#  [ 5 18 20 23 30 34]
#  [ 5  6 11 17 38 44]
#  [ 2 12 37 39 41 45]
#  [ 9 11 27 31 32 38]
#  [13 21 22 24 26 37]
#  [26 27 28 42 43 45]
#  [ 2  3 12 20 27 38]
#  [ 2 11 21 34 41 42]]
# RandomForest :  [[ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 2 12 18 21 28 45]
#  [ 1 10 18 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 27 34 45]
#  [ 1 10 20 24 34 45]
#  [ 1  7 13 33 34 45]
#  [ 1 10 13 31 34 45]
#  [ 1 10 18 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 17 19 23 37 45]
#  [ 1 10 20 27 34 45]
#  [ 1 10 18 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 29 34 45]
#  [ 1 10 13 31 34 45]
#  [ 1 10 13 31 34 45]
#  [ 1 10 15 26 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  7 13 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 24 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 13 23 40 44]
#  [ 1 10 20 24 34 45]
#  [ 1 10 20 31 34 45]
#  [ 3 13 19 23 35 44]
#  [ 1  8 13 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 13 26 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 13 26 38 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 24 34 45]
#  [ 1 10 13 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  8 13 31 34 45]
#  [ 1 10 20 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 13 26 38 45]
#  [ 1 10 20 29 39 45]
#  [ 1  8 13 31 34 45]
#  [ 1  8 19 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 24 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  8 13 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1 10 13 26 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 27 34 45]
#  [ 1 10 20 24 34 45]
#  [ 1 10 20 27 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 13 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 26 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  7 19 33 39 45]
#  [ 1 10 20 31 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1  8 19 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 27 34 45]
#  [ 1 10 19 31 34 45]
#  [ 1  8 13 31 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 20 24 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 18 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 13 27 38 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 31 34 45]
#  [ 1 10 20 24 34 45]
#  [ 1 10 20 27 34 45]
#  [ 1 10 20 31 34 45]]

# %%
# 평가용 함수 - 분류
from sklearn.metrics import mean_squared_error

print(np.sqrt(mean_squared_error(yval, pred1)))
print(np.sqrt(mean_squared_error(yval, pred4)))
print(np.sqrt(mean_squared_error(yval, pred5)))
# Out:
# 7.911204457179878
# 9.353816536155117
# 7.849112223119982

# %%
# from sklearn.ensemble import RandomForestRegressor

# model = RandomForestRegressor(random_state = 202307,
#                               max_depth = 3,
#                               n_estimators= 5)
# model.fit(Xtr, ytr)

# rpred = model.predict(Xval)
# rpred

# %%
# from sklearn.metrics import mean_squared_error

# print(np.sqrt(mean_squared_error(yval, rpred)))

# %%
# from sklearn.ensemble import RandomForestClassifier

# model2 = RandomForestClassifier(random_state = 202307,
#                               max_depth = 5,
#                               n_estimators= 100)
# model2.fit(Xtr, ytr)

# rpred2 = model2.predict(Xval)
# rpred2

# %%
# from sklearn.metrics import roc_auc_score

# print(roc_auc_score(yval, rpred2))

# %%
pred = model1.predict(Xtest)
pred
# Out:
# array([[ 1,  7, 18, 27, 34, 45],
#        [ 1,  7, 13, 27, 34, 45],
#        [ 1,  7, 13, 27, 34, 45],
#        [ 1,  7, 13, 27, 34, 45],
#        [ 1,  7, 13, 27, 34, 45],
#        [ 1,  7, 18, 27, 34, 45],
#        [ 1,  7, 13, 27, 34, 45]])

# %%
predi = model4.predict(Xtest)
predi
# Out:
# array([[10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41]])

# %%
predo = model5.predict(Xtest)
predo
# Out:
# array([[ 4, 12, 18, 22, 31, 33],
#        [ 4, 12, 18, 22, 31, 33],
#        [ 4, 12, 18, 22, 31, 33],
#        [ 4, 12, 18, 22, 31, 33],
#        [ 4, 12, 18, 22, 31, 33],
#        [ 4, 12, 18, 22, 31, 33],
#        [ 4, 12, 18, 22, 31, 33]])
