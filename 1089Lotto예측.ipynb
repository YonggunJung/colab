# %% [markdown]
# <a href="https://colab.research.google.com/github/YonggunJung/colab/blob/main/1089Lotto%EC%98%88%EC%B8%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/로또/data/lotto.csv')
df
# Out:
#        1   2   3   4   5   6     일     이     삼     사     오     육
# 0      4   7  17  18  38  44   8.0  12.0  13.0  29.0  33.0  42.0
# 1      8  12  13  29  33  42   3.0   7.0  14.0  15.0  22.0  38.0
# 2      3   7  14  15  22  38  21.0  26.0  27.0  32.0  34.0  42.0
# 3     21  26  27  32  34  42   1.0   9.0  16.0  23.0  24.0  38.0
# 4      1   9  16  23  24  38  13.0  16.0  23.0  31.0  36.0  44.0
# ...   ..  ..  ..  ..  ..  ..   ...   ...   ...   ...   ...   ...
# 1083   9  13  21  25  32  42  10.0  23.0  29.0  33.0  37.0  40.0
# 1084  10  23  29  33  37  40  11.0  16.0  25.0  27.0  35.0  36.0
# 1085  11  16  25  27  35  36  13.0  14.0  18.0  21.0  34.0  44.0
# 1086  13  14  18  21  34  44  11.0  21.0  22.0  30.0  39.0  44.0
# 1087  11  21  22  30  39  44   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1088 rows x 12 columns]

# %%
Xtrain = df.drop(['일', '이', '삼', '사','오', '육'], axis = 1)
Xtrain
# Out:
#        1   2   3   4   5   6
# 0      4   7  17  18  38  44
# 1      8  12  13  29  33  42
# 2      3   7  14  15  22  38
# 3     21  26  27  32  34  42
# 4      1   9  16  23  24  38
# ...   ..  ..  ..  ..  ..  ..
# 1083   9  13  21  25  32  42
# 1084  10  23  29  33  37  40
# 1085  11  16  25  27  35  36
# 1086  13  14  18  21  34  44
# 1087  11  21  22  30  39  44
#
# [1088 rows x 6 columns]

# %%
Xtest = Xtrain.loc[1087]
Xtest
# Out:
# 1    11
# 2    21
# 3    22
# 4    30
# 5    39
# 6    44
# Name: 1087, dtype: int64

# %%
Xtrain.drop(1087, inplace = True)
Xtrain
# Out:
#        1   2   3   4   5   6
# 0      4   7  17  18  38  44
# 1      8  12  13  29  33  42
# 2      3   7  14  15  22  38
# 3     21  26  27  32  34  42
# 4      1   9  16  23  24  38
# ...   ..  ..  ..  ..  ..  ..
# 1082  11  16  19  21  27  31
# 1083   9  13  21  25  32  42
# 1084  10  23  29  33  37  40
# 1085  11  16  25  27  35  36
# 1086  13  14  18  21  34  44
#
# [1087 rows x 6 columns]

# %%
ytrain = df.drop(['1', '2', '3', '4','5', '6'], axis = 1)
ytrain
# Out:
#          일     이     삼     사     오     육
# 0      8.0  12.0  13.0  29.0  33.0  42.0
# 1      3.0   7.0  14.0  15.0  22.0  38.0
# 2     21.0  26.0  27.0  32.0  34.0  42.0
# 3      1.0   9.0  16.0  23.0  24.0  38.0
# 4     13.0  16.0  23.0  31.0  36.0  44.0
# ...    ...   ...   ...   ...   ...   ...
# 1083  10.0  23.0  29.0  33.0  37.0  40.0
# 1084  11.0  16.0  25.0  27.0  35.0  36.0
# 1085  13.0  14.0  18.0  21.0  34.0  44.0
# 1086  11.0  21.0  22.0  30.0  39.0  44.0
# 1087   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1088 rows x 6 columns]

# %%
ytrain.dropna(inplace = True)
ytrain
# Out:
#          일     이     삼     사     오     육
# 0      8.0  12.0  13.0  29.0  33.0  42.0
# 1      3.0   7.0  14.0  15.0  22.0  38.0
# 2     21.0  26.0  27.0  32.0  34.0  42.0
# 3      1.0   9.0  16.0  23.0  24.0  38.0
# 4     13.0  16.0  23.0  31.0  36.0  44.0
# ...    ...   ...   ...   ...   ...   ...
# 1082   9.0  13.0  21.0  25.0  32.0  42.0
# 1083  10.0  23.0  29.0  33.0  37.0  40.0
# 1084  11.0  16.0  25.0  27.0  35.0  36.0
# 1085  13.0  14.0  18.0  21.0  34.0  44.0
# 1086  11.0  21.0  22.0  30.0  39.0  44.0
#
# [1087 rows x 6 columns]

# %%
ytrain =ytrain.astype(int)
ytrain
# Out:
#        일   이   삼   사   오   육
# 0      8  12  13  29  33  42
# 1      3   7  14  15  22  38
# 2     21  26  27  32  34  42
# 3      1   9  16  23  24  38
# 4     13  16  23  31  36  44
# ...   ..  ..  ..  ..  ..  ..
# 1082   9  13  21  25  32  42
# 1083  10  23  29  33  37  40
# 1084  11  16  25  27  35  36
# 1085  13  14  18  21  34  44
# 1086  11  21  22  30  39  44
#
# [1087 rows x 6 columns]

# %%
from pandas import get_dummies

Xtrain = pd.get_dummies(Xtrain)
Xtest = pd.get_dummies(Xtest)
Xtest
# Out:
#    11  21  22  30  39  44
# 1   1   0   0   0   0   0
# 2   0   1   0   0   0   0
# 3   0   0   1   0   0   0
# 4   0   0   0   1   0   0
# 5   0   0   0   0   1   0
# 6   0   0   0   0   0   1

# %%
from sklearn.model_selection import train_test_split

Xtr, Xval, ytr, yval = train_test_split(Xtrain, ytrain,
                                        test_size = 0.1,
                                        random_state = 202309)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedGroupKFold
kfold = KFold(n_splits = 10, shuffle = True, random_state = 202309)

# %%
# !pip install KNN
# !pip install SVC
# !pip install decisiontree
# !pip install voting
# Out:
# Collecting KNN
#   Downloading KNN-1.0.0.tar.gz (2.4 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: KNN
#   Building wheel for KNN (setup.py) ... done
#   Created wheel for KNN: filename=KNN-1.0.0-py3-none-any.whl size=3111 sha256=33a59ef1df586dc75a076b7bce6eaa12ad305dde4cb5c90798934a1df2718af8
#   Stored in directory: /root/.cache/pip/wheels/db/f0/9c/9da3fdf7ad3d19587a688434d71dbf38ced30bde9fb2975ff7
# Successfully built KNN
# Installing collected packages: KNN
# Successfully installed KNN-1.0.0
# Collecting SVC
#   Downloading SVC-0.1.tar.gz (1.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: xlrd>=0.9.3 in /usr/local/lib/python3.10/dist-packages (from SVC) (2.0.1)
# Building wheels for collected packages: SVC
#   Building wheel for SVC (setup.py) ... done
#   Created wheel for SVC: filename=SVC-0.1-py3-none-any.whl size=1870 sha256=48bafe7c88606bc72d3118b5ea3dbfc413ba52b36b70dc6a30f4705a883150c3
#   Stored in directory: /root/.cache/pip/wheels/88/51/46/316b33cfa9e39d0749762daa17b6a8646e3050079185747370
# Successfully built SVC
# Installing collected packages: SVC
# Successfully installed SVC-0.1
# Collecting decisiontree
#   Downloading DecisionTree-3.4.3.tar.gz (335 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 335.3/335.3 kB 5.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: decisiontree
#   Building wheel for decisiontree (setup.py) ... done
#   Created wheel for decisiontree: filename=DecisionTree-3.4.3-py3-none-any.whl size=81843 sha256=29b6d9d9664cc68641cf1bfd7a0a056d6ba637ffe09e3e1010abb17b330e50b2
#   Stored in directory: /root/.cache/pip/wheels/59/d4/29/d88ed8e92d4c96a49d195c034b7f0e7ce74b10531fbfd98555
# Successfully built decisiontree
# Installing collected packages: decisiontree
# Successfully installed decisiontree-3.4.3
# Collecting voting
#   Downloading voting-0.1.3-py2.py3-none-any.whl (8.0 kB)
# Installing collected packages: voting
# Successfully installed voting-0.1.3

# %%
# 머신러닝 알고리즘 분류
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import VotingClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

model1 = KNeighborsClassifier(n_neighbors = 100)
model2 = LogisticRegression(random_state = 202309)
model3 = SVC(random_state = 202309, probability = True)
model4 = DecisionTreeClassifier(random_state = 202309,
                                max_depth = 50)
model5 = RandomForestClassifier(random_state = 202309,
                                max_depth = 2,
                                n_estimators= 5)
model6 = AdaBoostClassifier(random_state = 202309)
model7 = GradientBoostingClassifier(random_state = 202309)
model8 = LGBMClassifier(random_state = 202309)
model9 = XGBClassifier(random_state = 202309, silent = True, verbosity = 0)

# %%
model1.fit(Xtr, ytr)
# model2.fit(Xtr, ytr)
# model3.fit(Xtr, ytr)
model4.fit(Xtr, ytr)
model5.fit(Xtr, ytr)
# model6.fit(Xtr, ytr)
# model7.fit(Xtr, ytr)
# model8.fit(Xtr, ytr)
# model9.fit(Xtr, ytr)
# model10.fit(Xtr, ytr)
# model11.fit(Xtr, ytr)

pred1 = model1.predict(Xval)
# pred2 = model2.predict(Xval)
# pred3 = model3.predict(Xval)
pred4 = model4.predict(Xval)
pred5 = model5.predict(Xval)
# pred6 = model6.predict(Xval)
# pred7 = model7.predict(Xval)
# pred8 = model8.predict(Xval)
# pred9 = model9.predict(Xval)
# pred10 = model10.predict(Xval)
# pred11 = model11.predict(Xval)

print('KNN : ', pred1)
# print('LogisticRegression' + pred2)
# print('SVM' + pred3)
print('DecisionTree : ', + pred4)
print('RandomForest : ', + pred5)
# print('AdaBoost' + pred6)
# print('GradientBoost' + pred7)
# print('LGBM' + pred8)
# print('XGBoost' + pred9)
# print('Voting(hard)' + pred10)
# print('Voting(soft)' + pred11)
# Out:
# KNN :  [[ 1  4 20 19 33 44]
#  [ 2  8 11 27 34 45]
#  [ 1 14 13 24 34 45]
#  [ 1 11 20 21 34 44]
#  [ 1 10 13 33 34 43]
#  [ 2  8 20 30 34 45]
#  [ 1 11 12 30 39 43]
#  [ 5  7 13 27 39 45]
#  [ 1 12 18 21 38 45]
#  [ 1 12 18 21 35 45]
#  [ 3 10 20 21 31 45]
#  [ 3  7 13 26 39 44]
#  [ 1 12 11 18 34 45]
#  [ 3 10 13 31 33 43]
#  [ 1  8 14 24 34 45]
#  [ 4  9 15 26 32 45]
#  [ 1  9 12 27 33 45]
#  [ 1  9 29 31 34 44]
#  [ 1 11 18 35 37 45]
#  [ 2 12 19 24 34 44]
#  [ 2 14 20 32 34 44]
#  [ 2 10 12 27 33 44]
#  [ 1 10 12 27 34 45]
#  [ 3  4 13 33 34 45]
#  [ 2 10 13 25 33 43]
#  [ 1  9 20 31 34 43]
#  [ 2  8 13 17 33 45]
#  [ 1 12 13 26 39 44]
#  [ 4 12 22 33 38 45]
#  [ 1 12 20 33 38 39]
#  [ 2 11 13 31 34 44]
#  [ 2 19 13 32 33 43]
#  [ 3 10 13 26 39 43]
#  [ 1 11 12 27 37 45]
#  [ 1 10 12 33 40 43]
#  [ 2  7 13 32 35 43]
#  [ 2 11 13 32 37 44]
#  [ 4 12 15 32 37 45]
#  [ 2 12 20 27 34 44]
#  [ 1 12 17 16 39 45]
#  [ 3 11 20 31 34 45]
#  [ 1 12 20 31 34 44]
#  [ 1 10 13 33 34 40]
#  [ 2  7 15 33 36 45]
#  [ 1 10 19 32 33 44]
#  [ 2 12 20 31 34 44]
#  [ 3  4 16 19 33 45]
#  [ 3  8 20 33 33 40]
#  [ 1  8 12 27 33 45]
#  [ 1 14 20 24 31 44]
#  [ 2  9 20 24 31 45]
#  [ 2 10 11 24 34 40]
#  [ 2 10 16 24 33 44]
#  [ 1 14 28 23 34 44]
#  [ 2 11 20 19 33 45]
#  [ 1  4 13 19 34 45]
#  [ 3  7 13 26 39 45]
#  [ 2 16 16 29 34 45]
#  [ 2 11 18 31 31 45]
#  [ 1 10 15 31 34 45]
#  [ 2 11 14 24 34 44]
#  [ 1 13 18 21 34 45]
#  [ 2  7 14 27 41 45]
#  [ 1 10 20 26 31 45]
#  [ 1 10 15 32 38 44]
#  [ 2 14 15 24 31 45]
#  [ 1  8 14 27 34 45]
#  [ 1  8 14 27 34 45]
#  [ 2  7 14 27 41 45]
#  [ 1  7 14 27 36 45]
#  [ 3 10 13 31 32 40]
#  [ 1 10 16 32 36 45]
#  [ 3  4 20 33 34 40]
#  [ 1 14 20 24 34 45]
#  [ 1 11 12 30 39 45]
#  [ 1 11 29 23 34 44]
#  [ 4  7 24 27 37 45]
#  [ 2  7 17 31 41 45]
#  [ 3 10 20 20 39 45]
#  [ 3 11 13 31 33 43]
#  [ 1  7 17 27 34 43]
#  [ 2 10 13 27 33 44]
#  [ 1 11 10 25 34 40]
#  [ 2  8 18 30 31 45]
#  [ 1 11 14 17 33 45]
#  [ 1 12 29 31 34 44]
#  [ 2 12 26 31 37 43]
#  [ 2  7 11 27 34 44]
#  [ 2  8 20 27 33 45]
#  [ 2 11 20 23 34 43]
#  [ 3  4 15 20 34 40]
#  [ 1  8 14 27 34 45]
#  [ 1  4 22 33 41 40]
#  [ 4  8 13 27 39 45]
#  [ 3  7 13 16 39 43]
#  [ 1  7 15 26 36 45]
#  [ 1  7 18 26 38 45]
#  [ 1 16 13 33 34 40]
#  [ 3  4 11 33 34 45]
#  [ 2 18 20 27 34 43]
#  [ 4 11 15 27 36 44]
#  [ 3  7 15 26 39 43]
#  [ 1 11 18 27 37 45]
#  [ 2 14 20 32 33 44]
#  [ 1  8 11 27 34 45]
#  [ 1 12 20 31 39 44]
#  [ 2 11 14 31 33 44]
#  [ 1  4 18 31 34 42]
#  [ 4 10 16 27 33 45]]
# DecisionTree :  [[ 2  8 33 35 37 41]
#  [ 2 12 37 39 41 45]
#  [10 14 16 18 29 35]
#  [ 2  3 22 27 30 40]
#  [ 4  5 15 16 22 42]
#  [ 9 10 15 30 33 37]
#  [ 7  8 11 16 41 44]
#  [ 2  7 13 25 42 45]
#  [ 1 11 12 14 26 35]
#  [ 1  2  6 16 20 33]
#  [10 14 16 18 29 35]
#  [ 4 13 18 31 33 45]
#  [12 15 28 36 39 40]
#  [ 1 11 13 24 28 40]
#  [ 1 10 20 32 35 40]
#  [12 20 26 33 44 45]
#  [10 14 30 31 33 37]
#  [ 2 16 19 31 34 35]
#  [ 7 16 18 20 23 26]
#  [ 7 16 31 36 37 38]
#  [ 4 15 28 33 37 40]
#  [16 23 27 29 33 41]
#  [ 5  9 14 26 30 43]
#  [ 6  8 13 23 31 36]
#  [ 5 21 27 34 44 45]
#  [ 2 16 19 31 34 35]
#  [ 2  6 13 17 27 43]
#  [ 1 10 13 16 37 43]
#  [ 6 12 15 34 42 44]
#  [ 6  9 18 19 25 33]
#  [ 4 11 14 21 23 43]
#  [ 8 19 25 34 37 39]
#  [ 5  9 12 16 29 41]
#  [ 8 17 18 24 39 45]
#  [ 5  9 12 30 39 43]
#  [ 8 19 25 34 37 39]
#  [ 3 19 22 31 42 43]
#  [ 1  4  8 23 33 42]
#  [ 5 15 21 23 25 45]
#  [11 12 18 21 31 38]
#  [ 6 11 19 20 28 32]
#  [15 20 23 26 39 44]
#  [ 4  5 11 12 24 27]
#  [ 9 14 34 35 41 42]
#  [ 1 13 20 22 25 28]
#  [ 2  8 15 22 25 41]
#  [ 1 27 28 32 37 40]
#  [ 1 11 13 24 28 40]
#  [ 9 12 15 25 34 36]
#  [17 21 31 37 40 44]
#  [ 2 18 29 32 43 44]
#  [ 1 11 13 24 28 40]
#  [ 1 13 20 22 25 28]
#  [ 4 24 25 27 34 35]
#  [ 3  5 13 20 21 37]
#  [15 17 19 34 38 41]
#  [ 1 26 31 34 40 43]
#  [ 2 19 25 26 27 43]
#  [12 24 33 38 40 42]
#  [11 12 25 32 44 45]
#  [ 1  2  3 15 20 25]
#  [ 1  2 11 21 30 35]
#  [ 8 13 14 30 38 39]
#  [19 23 25 28 38 42]
#  [ 6  7 22 32 35 36]
#  [ 3  4 12 14 25 43]
#  [ 1  2 16 22 38 39]
#  [ 7 24 29 30 34 35]
#  [ 4 10 14 15 18 22]
#  [ 1  7 11 23 37 42]
#  [13 19 28 37 38 43]
#  [ 1 13 20 22 25 28]
#  [ 5  7  8 15 30 43]
#  [ 9 30 34 35 39 41]
#  [ 7 10 19 22 35 40]
#  [ 2  9 15 23 34 40]
#  [ 7 12 19 21 29 32]
#  [14 19 25 26 27 34]
#  [ 8 21 25 39 40 44]
#  [11 16 18 19 24 39]
#  [ 1  7 36 37 41 42]
#  [ 1  2 10 13 18 19]
#  [ 1  5  6 24 27 42]
#  [ 4  8 27 34 39 40]
#  [ 1  4 13 29 38 39]
#  [ 3 12 20 23 31 35]
#  [ 2  5 10 18 31 32]
#  [ 3  4  6 10 28 30]
#  [ 5 13 14 20 24 25]
#  [14 23 26 31 39 45]
#  [ 1 21 25 29 34 37]
#  [ 1  9 17 21 29 33]
#  [ 6  9 11 22 24 30]
#  [17 18 31 32 33 34]
#  [11 22 24 32 36 38]
#  [14 25 31 34 40 44]
#  [16 19 24 33 42 44]
#  [ 7 16 25 29 35 36]
#  [ 7 10 22 25 34 40]
#  [ 3 10 11 22 36 39]
#  [ 6  8 18 35 42 43]
#  [ 5 14 15 23 34 43]
#  [11 16 19 21 27 31]
#  [ 2  6 11 13 22 37]
#  [ 3  8  9 27 29 40]
#  [ 8 14 23 36 38 39]
#  [ 4  5  9 11 23 38]
#  [14 27 30 31 40 42]
#  [ 3  9 10 29 40 45]]
# RandomForest :  [[ 1 11 18 33 39 43]
#  [ 1  7 18 27 37 44]
#  [ 1 11 18 27 34 45]
#  [ 1  7 18 27 37 44]
#  [ 1 12 13 21 32 45]
#  [ 1 11 18 27 34 45]
#  [ 1 15 15 27 30 45]
#  [ 1 11 13 26 34 45]
#  [ 1 11 18 26 34 45]
#  [ 1 11 13 26 34 45]
#  [ 1 11 18 27 34 45]
#  [ 1 11 13 26 34 45]
#  [ 1 10 13 26 37 45]
#  [ 1 15 13 33 37 45]
#  [ 1 11 18 27 34 45]
#  [ 1 11 18 26 34 45]
#  [ 1 10 13 26 37 45]
#  [ 1 11 18 27 34 45]
#  [ 1 11 18 31 34 45]
#  [ 1 11 18 31 39 44]
#  [ 1 11 18 27 34 45]
#  [ 1  7 18 27 37 44]
#  [ 1 11 18 27 34 45]
#  [ 1 15 13 33 37 45]
#  [ 1 11 18 31 34 45]
#  [ 1 11 18 24 34 45]
#  [ 1  7 18 27 37 44]
#  [ 1 11 13 26 34 45]
#  [ 1 11 18 26 34 45]
#  [ 1 11 18 26 34 45]
#  [ 1 11 18 33 39 43]
#  [ 1  7 18 27 37 44]
#  [ 1 11 13 26 34 45]
#  [ 1 11 18 33 39 43]
#  [ 3  7  8 34 39 41]
#  [ 1  7 18 27 37 44]
#  [ 1  7 18 27 37 44]
#  [ 1  7 18 27 37 44]
#  [ 2 20 23 34 38 43]
#  [ 1 11 13 26 34 45]
#  [ 1 11 18 33 39 43]
#  [ 1 11 18 27 34 45]
#  [ 1 11 18 33 39 43]
#  [ 1 11 18 31 34 45]
#  [ 1 11 18 27 34 45]
#  [ 1 11 18 27 34 45]
#  [ 1 11 18 31 34 45]
#  [ 1 11 18 33 39 43]
#  [ 1 11 18 27 34 45]
#  [ 1 11 18 27 34 45]
#  [ 1 11 18 27 34 45]
#  [ 1 15 13 35 37 45]
#  [ 1 11 18 27 34 45]
#  [ 1 11 18 27 34 45]
#  [ 1 11 18 33 39 43]
#  [ 1 11 18 33 39 43]
#  [ 1 11 13 26 34 45]
#  [ 1  7 18 27 37 44]
#  [ 1 11 18 33 39 43]
#  [ 1 11 18 24 34 45]
#  [ 1 11 18 27 34 45]
#  [ 1 11 18 27 34 45]
#  [ 1  7 18 27 37 44]
#  [ 1 10 13 26 37 45]
#  [ 1 11 18 26 34 45]
#  [ 1 11 18 27 34 45]
#  [ 1 11 18 27 34 45]
#  [ 1 11 18 27 34 45]
#  [ 1 10 13 26 37 45]
#  [ 1 10 13 26 37 45]
#  [ 1 11 18 33 39 43]
#  [ 1 11 18 26 34 45]
#  [ 1 11 18 31 34 45]
#  [ 1 11 18 27 34 45]
#  [ 7 10 19 22 35 40]
#  [ 1 11 18 26 34 45]
#  [ 1  7 18 27 37 44]
#  [ 1 10 13 26 37 45]
#  [ 1 17 15 27 42 43]
#  [ 1 15 13 33 37 45]
#  [ 1 15 13 35 37 45]
#  [ 1 11 18 26 34 45]
#  [ 1 11 18 26 34 45]
#  [ 1 11 18 31 34 45]
#  [ 1 11 18 27 34 45]
#  [ 1 11 18 27 34 45]
#  [ 1  7 18 27 37 44]
#  [ 1 10 13 26 37 45]
#  [ 1 11 18 27 34 45]
#  [ 1 11 18 31 34 45]
#  [ 1 11 18 31 34 45]
#  [ 1 11 18 27 34 45]
#  [ 1 11 18 33 39 43]
#  [ 1  7 18 27 37 44]
#  [ 1 11 13 26 34 45]
#  [ 1 11 18 26 34 45]
#  [ 1 11 18 26 34 45]
#  [ 1 15 13 33 37 45]
#  [ 1 10 13 26 37 45]
#  [ 1 15 13 35 37 45]
#  [ 1  7 18 27 37 44]
#  [ 1 11 13 26 34 45]
#  [ 1 11 18 33 39 43]
#  [ 1 11 18 31 34 45]
#  [ 1 11 18 27 34 45]
#  [ 1  7 18 27 37 44]
#  [ 1 11 18 27 34 45]
#  [ 1 11 18 33 39 43]
#  [ 1 11 18 26 34 45]]

# %%
# 평가용 함수 - 분류
from sklearn.metrics import mean_squared_error

print(np.sqrt(mean_squared_error(yval, pred1)))
print(np.sqrt(mean_squared_error(yval, pred4)))
print(np.sqrt(mean_squared_error(yval, pred5)))
# Out:
# 7.770405709676063
# 9.528084994883535
# 7.699438003240836

# %%
# from sklearn.ensemble import RandomForestRegressor

# model = RandomForestRegressor(random_state = 202307,
#                               max_depth = 3,
#                               n_estimators= 5)
# model.fit(Xtr, ytr)

# rpred = model.predict(Xval)
# rpred

# %%
# from sklearn.metrics import mean_squared_error

# print(np.sqrt(mean_squared_error(yval, rpred)))

# %%
# from sklearn.ensemble import RandomForestClassifier

# model2 = RandomForestClassifier(random_state = 202307,
#                               max_depth = 5,
#                               n_estimators= 100)
# model2.fit(Xtr, ytr)

# rpred2 = model2.predict(Xval)
# rpred2

# %%
# from sklearn.metrics import roc_auc_score

# print(roc_auc_score(yval, rpred2))

# %%
pred = model1.predict(Xtest)
pred
# Out:
# array([[ 1, 12, 13, 16, 39, 44],
#        [ 1, 12, 13, 16, 39, 44],
#        [ 1, 12, 13, 16, 39, 44],
#        [ 1, 12, 13, 16, 39, 44],
#        [ 1, 12, 13, 16, 39, 44],
#        [ 1, 12, 13, 16, 39, 44]])

# %%
predi = model4.predict(Xtest)
predi
# Out:
# array([[10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41]])

# %%
predo = model5.predict(Xtest)
predo
# Out:
# array([[ 1, 11, 13, 26, 34, 45],
#        [ 1, 11, 13, 26, 34, 45],
#        [ 1, 11, 13, 26, 34, 45],
#        [ 1, 11, 13, 26, 34, 45],
#        [ 1, 11, 13, 26, 34, 45],
#        [ 1, 11, 13, 26, 34, 45]])
