# %% [markdown]
# <a href="https://colab.research.google.com/github/YonggunJung/colab/blob/main/1099Lotto2%EC%98%88%EC%B8%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/로또/data/lotto2.csv')
df
# Out:
#        1   2   3   4   5   6  보너스     일     이     삼     사     오     육
# 0     11  21  22  30  39  44   31  13.0  14.0  18.0  21.0  34.0  44.0
# 1     13  14  18  21  34  44   16  11.0  16.0  25.0  27.0  35.0  36.0
# 2     11  16  25  27  35  36   37   4.0   7.0  17.0  18.0  38.0  44.0
# 3      4   7  17  18  38  44   36   8.0  12.0  13.0  29.0  33.0  42.0
# 4      8  12  13  29  33  42    5   3.0   7.0  14.0  15.0  22.0  38.0
# ...   ..  ..  ..  ..  ..  ..  ...   ...   ...   ...   ...   ...   ...
# 1093   6   7  15  22  26  40   41   8.0  14.0  28.0  29.0  34.0  40.0
# 1094   8  14  28  29  34  40   12   1.0  12.0  16.0  19.0  23.0  43.0
# 1095   1  12  16  19  23  43   34  14.0  33.0  34.0  35.0  37.0  40.0
# 1096  14  33  34  35  37  40    4  12.0  16.0  21.0  24.0  41.0  43.0
# 1097  12  16  21  24  41  43   15   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1098 rows x 13 columns]

# %%
Xtrain = df.drop(['일', '이', '삼', '사','오', '육'], axis = 1)
Xtrain
# Out:
#        1   2   3   4   5   6  보너스
# 0     11  21  22  30  39  44   31
# 1     13  14  18  21  34  44   16
# 2     11  16  25  27  35  36   37
# 3      4   7  17  18  38  44   36
# 4      8  12  13  29  33  42    5
# ...   ..  ..  ..  ..  ..  ..  ...
# 1093   6   7  15  22  26  40   41
# 1094   8  14  28  29  34  40   12
# 1095   1  12  16  19  23  43   34
# 1096  14  33  34  35  37  40    4
# 1097  12  16  21  24  41  43   15
#
# [1098 rows x 7 columns]

# %%
Xtest = Xtrain.iloc[Xtrain.index[-1]]
Xtest
# Out:
# 1      12
# 2      16
# 3      21
# 4      24
# 5      41
# 6      43
# 보너스    15
# Name: 1097, dtype: int64

# %%
Xtrain.drop(Xtrain.index[-1], inplace = True)
Xtrain
# Out:
#        1   2   3   4   5   6  보너스
# 0     11  21  22  30  39  44   31
# 1     13  14  18  21  34  44   16
# 2     11  16  25  27  35  36   37
# 3      4   7  17  18  38  44   36
# 4      8  12  13  29  33  42    5
# ...   ..  ..  ..  ..  ..  ..  ...
# 1092  10  17  22  30  35  43   44
# 1093   6   7  15  22  26  40   41
# 1094   8  14  28  29  34  40   12
# 1095   1  12  16  19  23  43   34
# 1096  14  33  34  35  37  40    4
#
# [1097 rows x 7 columns]

# %%
ytrain = df.drop(['1', '2', '3', '4','5', '6', '보너스'], axis = 1)
ytrain
# Out:
#          일     이     삼     사     오     육
# 0     13.0  14.0  18.0  21.0  34.0  44.0
# 1     11.0  16.0  25.0  27.0  35.0  36.0
# 2      4.0   7.0  17.0  18.0  38.0  44.0
# 3      8.0  12.0  13.0  29.0  33.0  42.0
# 4      3.0   7.0  14.0  15.0  22.0  38.0
# ...    ...   ...   ...   ...   ...   ...
# 1093   8.0  14.0  28.0  29.0  34.0  40.0
# 1094   1.0  12.0  16.0  19.0  23.0  43.0
# 1095  14.0  33.0  34.0  35.0  37.0  40.0
# 1096  12.0  16.0  21.0  24.0  41.0  43.0
# 1097   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1098 rows x 6 columns]

# %%
ytrain.dropna(inplace = True)
ytrain
# Out:
#          일     이     삼     사     오     육
# 0     13.0  14.0  18.0  21.0  34.0  44.0
# 1     11.0  16.0  25.0  27.0  35.0  36.0
# 2      4.0   7.0  17.0  18.0  38.0  44.0
# 3      8.0  12.0  13.0  29.0  33.0  42.0
# 4      3.0   7.0  14.0  15.0  22.0  38.0
# ...    ...   ...   ...   ...   ...   ...
# 1092   6.0   7.0  15.0  22.0  26.0  40.0
# 1093   8.0  14.0  28.0  29.0  34.0  40.0
# 1094   1.0  12.0  16.0  19.0  23.0  43.0
# 1095  14.0  33.0  34.0  35.0  37.0  40.0
# 1096  12.0  16.0  21.0  24.0  41.0  43.0
#
# [1097 rows x 6 columns]

# %%
ytrain =ytrain.astype(int)
ytrain
# Out:
#        일   이   삼   사   오   육
# 0     13  14  18  21  34  44
# 1     11  16  25  27  35  36
# 2      4   7  17  18  38  44
# 3      8  12  13  29  33  42
# 4      3   7  14  15  22  38
# ...   ..  ..  ..  ..  ..  ..
# 1092   6   7  15  22  26  40
# 1093   8  14  28  29  34  40
# 1094   1  12  16  19  23  43
# 1095  14  33  34  35  37  40
# 1096  12  16  21  24  41  43
#
# [1097 rows x 6 columns]

# %%
from pandas import get_dummies

Xtrain = pd.get_dummies(Xtrain)
Xtest = pd.get_dummies(Xtest)
Xtest
# Out:
#      12  15  16  21  24  41  43
# 1     1   0   0   0   0   0   0
# 2     0   0   1   0   0   0   0
# 3     0   0   0   1   0   0   0
# 4     0   0   0   0   1   0   0
# 5     0   0   0   0   0   1   0
# 6     0   0   0   0   0   0   1
# 보너스   0   1   0   0   0   0   0

# %%
from sklearn.model_selection import train_test_split

Xtr, Xval, ytr, yval = train_test_split(Xtrain, ytrain,
                                        test_size = 0.1,
                                        random_state = 202309)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedGroupKFold
kfold = KFold(n_splits = 10, shuffle = True, random_state = 202309)

# %%
# !pip install KNN
# !pip install SVC
# !pip install decisiontree
# !pip install voting
# Out:
# Collecting KNN
#   Downloading KNN-1.0.0.tar.gz (2.4 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: KNN
#   Building wheel for KNN (setup.py) ... done
#   Created wheel for KNN: filename=KNN-1.0.0-py3-none-any.whl size=3109 sha256=799429d99f562929c7f7b99759be76a4e16bc314e0bdfaf182c4211cc4c043ef
#   Stored in directory: /root/.cache/pip/wheels/db/f0/9c/9da3fdf7ad3d19587a688434d71dbf38ced30bde9fb2975ff7
# Successfully built KNN
# Installing collected packages: KNN
# Successfully installed KNN-1.0.0
# Collecting SVC
#   Downloading SVC-0.1.tar.gz (1.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: xlrd>=0.9.3 in /usr/local/lib/python3.10/dist-packages (from SVC) (2.0.1)
# Building wheels for collected packages: SVC
#   Building wheel for SVC (setup.py) ... done
#   Created wheel for SVC: filename=SVC-0.1-py3-none-any.whl size=1872 sha256=bacc26af2ca4083baa9e91c136b1ac6e13ee80aa80af37735059130eb46a1898
#   Stored in directory: /root/.cache/pip/wheels/88/51/46/316b33cfa9e39d0749762daa17b6a8646e3050079185747370
# Successfully built SVC
# Installing collected packages: SVC
# Successfully installed SVC-0.1
# Collecting decisiontree
#   Downloading DecisionTree-3.4.3.tar.gz (335 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 335.3/335.3 kB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: decisiontree
#   Building wheel for decisiontree (setup.py) ... done
#   Created wheel for decisiontree: filename=DecisionTree-3.4.3-py3-none-any.whl size=81841 sha256=fe8d6ccb45b18cde5c1911c41e385fd6bcdd5febfb5791d043d6f1fad4f74f24
#   Stored in directory: /root/.cache/pip/wheels/59/d4/29/d88ed8e92d4c96a49d195c034b7f0e7ce74b10531fbfd98555
# Successfully built decisiontree
# Installing collected packages: decisiontree
# Successfully installed decisiontree-3.4.3
# Collecting voting
#   Downloading voting-0.1.3-py2.py3-none-any.whl (8.0 kB)
# Installing collected packages: voting
# Successfully installed voting-0.1.3

# %%
# 머신러닝 알고리즘 분류
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import VotingClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

model1 = KNeighborsClassifier(n_neighbors = 300,
                              leaf_size = 7)
model2 = LogisticRegression(random_state = 202309)
model3 = SVC(random_state = 202309, probability = True)
model4 = DecisionTreeClassifier(random_state = 202309,
                                max_depth = 50)
model5 = RandomForestClassifier(random_state = 202309,
                                max_depth = 2,
                                n_estimators= 60)
model6 = AdaBoostClassifier(random_state = 202309)
model7 = GradientBoostingClassifier(random_state = 202309)
model8 = LGBMClassifier(random_state = 202309)
model9 = XGBClassifier(random_state = 202309, silent = True, verbosity = 0)

# %%
model1.fit(Xtr, ytr)
# model2.fit(Xtr, ytr)
# model3.fit(Xtr, ytr)
model4.fit(Xtr, ytr)
model5.fit(Xtr, ytr)
# model6.fit(Xtr, ytr)
# model7.fit(Xtr, ytr)
# model8.fit(Xtr, ytr)
# model9.fit(Xtr, ytr)
# model10.fit(Xtr, ytr)
# model11.fit(Xtr, ytr)

pred1 = model1.predict(Xval)
# pred2 = model2.predict(Xval)
# pred3 = model3.predict(Xval)
pred4 = model4.predict(Xval)
pred5 = model5.predict(Xval)
# pred6 = model6.predict(Xval)
# pred7 = model7.predict(Xval)
# pred8 = model8.predict(Xval)
# pred9 = model9.predict(Xval)
# pred10 = model10.predict(Xval)
# pred11 = model11.predict(Xval)

print('KNN : ', pred1)
# print('LogisticRegression' + pred2)
# print('SVM' + pred3)
print('DecisionTree : ', + pred4)
print('RandomForest : ', + pred5)
# print('AdaBoost' + pred6)
# print('GradientBoost' + pred7)
# print('LGBM' + pred8)
# print('XGBoost' + pred9)
# print('Voting(hard)' + pred10)
# print('Voting(soft)' + pred11)
# Out:
# KNN :  [[ 1 10 16 30 34 45]
#  [ 2 10 20 30 34 45]
#  [ 1  9 16 27 38 45]
#  [ 1  8 19 27 34 45]
#  [ 1 11 16 33 33 45]
#  [ 1 11 16 27 33 45]
#  [ 1 11 16 31 38 45]
#  [ 1  8 18 33 34 43]
#  [ 1  8 15 33 33 45]
#  [ 1 12 18 31 34 43]
#  [ 1  7 13 27 39 45]
#  [ 2  7 20 27 34 45]
#  [ 2  8 20 30 34 45]
#  [ 1  8 18 23 37 45]
#  [ 1 11 15 30 34 43]
#  [ 1  7 20 26 39 45]
#  [ 1  8 18 33 34 43]
#  [ 1  8 13 31 34 43]
#  [ 2  7 13 27 34 45]
#  [ 1  8 18 31 34 43]
#  [ 1  8 16 31 34 45]
#  [ 1  7 13 27 39 45]
#  [ 1  8 16 24 33 45]
#  [ 1 11 16 21 34 45]
#  [ 1  9 16 27 33 45]
#  [ 1  5 14 27 38 45]
#  [ 1  8 19 33 34 45]
#  [ 2  7 20 27 39 45]
#  [ 1  8 16 33 33 45]
#  [ 1  8 16 23 33 44]
#  [ 1  8 18 30 34 43]
#  [ 2  7 20 27 34 44]
#  [ 2  7 13 27 39 44]
#  [ 1  8 16 31 34 45]
#  [ 1  8 18 21 34 45]
#  [ 1 10 20 30 34 45]
#  [ 1  8 18 23 34 45]
#  [ 1 11 16 32 33 43]
#  [ 1 10 13 26 39 45]
#  [ 1 11 16 23 33 45]
#  [ 1 10 13 26 39 45]
#  [ 1 10 20 35 34 45]
#  [ 1  8 19 27 34 45]
#  [ 1  8 19 33 34 44]
#  [ 1  8 19 33 34 43]
#  [ 1 12 13 27 39 45]
#  [ 2  7 13 27 34 44]
#  [ 1  8 18 33 40 45]
#  [ 2  7 20 27 34 44]
#  [ 2 10 20 27 34 45]
#  [ 1  9 20 27 38 45]
#  [ 2 14 20 30 34 45]
#  [ 1  8 16 27 33 45]
#  [ 1 10 20 31 38 45]
#  [ 1  8 13 31 34 45]
#  [ 1 12 19 23 34 44]
#  [ 1  7 13 27 34 45]
#  [ 2  8 20 30 38 45]
#  [ 1  8 16 25 33 45]
#  [ 1  8 13 31 34 43]
#  [ 1  7 13 26 34 45]
#  [ 1  7 13 27 34 45]
#  [ 2  7 20 27 34 45]
#  [ 1  8 13 23 34 43]
#  [ 1 10 20 27 39 45]
#  [ 1  8 16 31 33 45]
#  [ 1 10 20 27 38 43]
#  [ 1  7 13 29 34 45]
#  [ 1 11 16 27 33 45]
#  [ 1 14 19 30 34 45]
#  [ 2  7 20 27 39 45]
#  [ 1 11 13 26 38 45]
#  [ 1  8 16 31 33 45]
#  [ 1  8 13 33 34 43]
#  [ 1  8 13 33 34 43]
#  [ 2 10 19 35 34 45]
#  [ 1 12 13 27 39 45]
#  [ 2  7 20 27 34 45]
#  [ 1  8 16 30 33 45]
#  [ 1 12 16 26 34 43]
#  [ 1 10 19 23 34 45]
#  [ 1 10 20 30 34 43]
#  [ 1  8 19 21 37 45]
#  [ 1  8 18 30 34 44]
#  [ 1  9 20 27 39 45]
#  [ 1 11 16 33 33 45]
#  [ 1  8 16 31 33 45]
#  [ 1  8 20 31 34 45]
#  [ 1 12 13 27 34 45]
#  [ 2 10 20 30 34 45]
#  [ 1  8 13 21 34 45]
#  [ 2  7 20 27 34 45]
#  [ 1 14 20 30 39 45]
#  [ 1  8 16 31 34 43]
#  [ 1  8 16 33 34 43]
#  [ 1 11 16 23 33 45]
#  [ 1  8 18 31 34 43]
#  [ 1 10 13 27 34 44]
#  [ 1  8 16 33 33 45]
#  [ 1 10 18 31 34 43]
#  [ 1  8 16 30 38 43]
#  [ 1  8 13 33 34 43]
#  [ 1  8 16 21 38 43]
#  [ 1  8 16 27 33 45]
#  [ 1  7 16 27 33 45]
#  [ 1  8 19 23 34 45]
#  [ 1  8 16 27 38 45]
#  [ 1  8 18 23 37 45]
#  [ 1  7 18 27 34 45]
#  [ 1  8 20 23 34 44]]
# DecisionTree :  [[ 8 19 25 34 37 39]
#  [ 3 10 16 19 31 39]
#  [ 5  7 12 22 28 41]
#  [ 5 17 25 31 39 40]
#  [ 2  4 20 34 35 43]
#  [ 2 17 19 24 37 41]
#  [ 2  9 22 25 31 45]
#  [ 3  8 17 23 38 45]
#  [ 1  3 12 21 26 41]
#  [ 1 17 27 28 29 40]
#  [ 1  2  3 14 27 42]
#  [ 2 18 24 34 40 42]
#  [11 18 21 36 37 43]
#  [13 14 18 21 34 44]
#  [12 18 22 23 30 34]
#  [12 20 26 33 44 45]
#  [10 16 18 20 25 31]
#  [ 7 10 16 25 29 44]
#  [ 1 10 20 32 35 40]
#  [13 19 28 37 38 43]
#  [17 21 31 37 40 44]
#  [ 1  7 19 26 27 35]
#  [ 4 11 20 26 35 37]
#  [19 26 30 33 35 39]
#  [17 23 27 35 38 43]
#  [ 7 11 13 17 18 29]
#  [19 23 25 28 38 42]
#  [12 27 29 38 41 45]
#  [11 18 21 26 38 43]
#  [ 1  5  6 14 20 39]
#  [ 6 29 36 39 41 45]
#  [ 3  5 10 17 30 31]
#  [ 1  8 11 13 22 38]
#  [ 5 13 17 18 33 42]
#  [14 15 25 28 29 30]
#  [17 21 23 30 34 44]
#  [ 6 14 19 21 23 31]
#  [ 3  9 10 29 40 45]
#  [ 3  4 10 17 19 22]
#  [ 5 16 21 26 34 42]
#  [ 1  5 13 26 29 34]
#  [12 19 21 29 40 45]
#  [14 15 18 21 26 35]
#  [ 2  7 26 29 40 43]
#  [20 30 33 35 36 44]
#  [ 7 18 22 24 31 34]
#  [ 5 11 14 27 29 36]
#  [ 6 12 20 26 29 38]
#  [ 5  9 27 29 37 40]
#  [ 4  5 14 35 42 45]
#  [ 3 11 21 30 38 45]
#  [18 20 24 27 31 42]
#  [ 4  9 28 33 36 45]
#  [ 5  6 13 14 17 20]
#  [ 8 17 18 24 39 45]
#  [10 12 13 15 25 29]
#  [ 6 10 22 31 35 40]
#  [ 7 16 17 33 36 40]
#  [ 2  8 14 25 29 45]
#  [ 2  3  5 11 27 39]
#  [ 4 11 20 23 32 39]
#  [ 7 37 38 39 40 44]
#  [ 7 13 30 39 41 45]
#  [12 13 32 33 40 41]
#  [14 19 27 28 30 45]
#  [ 1  6 12 19 36 42]
#  [15 21 31 32 41 43]
#  [ 5  6  8 11 22 26]
#  [ 8 19 25 31 34 36]
#  [ 3 22 25 29 32 44]
#  [19 23 29 33 35 43]
#  [ 7 20 22 25 38 40]
#  [17 23 27 35 38 43]
#  [11 16 19 22 29 36]
#  [ 6  8 28 33 38 39]
#  [ 1 15 19 40 42 44]
#  [ 2  5  7 14 16 40]
#  [ 7 17 18 28 30 45]
#  [13 15 21 29 39 43]
#  [ 1  2  9 17 19 42]
#  [11 16 18 19 24 39]
#  [ 5 17 21 25 36 44]
#  [ 3 13 16 23 24 35]
#  [11 15 24 39 41 44]
#  [ 4 19 20 26 30 35]
#  [ 4 15 17 26 36 37]
#  [15 26 28 34 41 42]
#  [11 14 22 35 37 39]
#  [ 3  6 22 23 24 38]
#  [ 6 14 19 21 23 31]
#  [ 6  8 28 33 38 39]
#  [ 2 12 14 33 40 41]
#  [ 2  5 14 28 31 32]
#  [19 26 28 31 33 36]
#  [11 12 16 26 29 44]
#  [ 9 17 19 30 35 42]
#  [ 9 14 20 22 33 34]
#  [ 1  4  8 13 37 39]
#  [ 6  7 15 22 34 39]
#  [ 4 20 26 28 35 40]
#  [ 9 30 34 35 39 41]
#  [ 8 10 18 30 32 34]
#  [13 14 15 26 35 39]
#  [ 7  8 27 29 36 43]
#  [ 4  7 16 19 33 40]
#  [ 1 21 24 26 29 42]
#  [ 1 11 15 17 25 39]
#  [ 1  4 37 38 40 45]
#  [ 2 10 12 15 22 44]
#  [10 12 13 15 25 29]]
# RandomForest :  [[ 1 10 13 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 18 31 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 18 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 18 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 20 27 34 45]
#  [ 1  8 20 27 34 45]
#  [ 1 12 13 33 40 44]
#  [ 1 10 13 31 34 45]
#  [ 1 10 20 27 34 45]
#  [ 1 10 18 27 34 45]
#  [ 1 10 19 31 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 13 31 34 45]
#  [ 1 10 13 31 34 45]
#  [ 1 10 13 31 34 45]
#  [ 1 10 18 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 20 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 13 33 34 45]
#  [ 1 10 18 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 12 18 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 13 31 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 13 31 34 45]
#  [ 1 10 13 23 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 20 27 34 45]
#  [ 1 12 13 33 34 45]
#  [ 1 10 13 31 34 45]
#  [ 1 10 20 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 20 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 18 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 12 13 33 40 44]
#  [ 1 10 18 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 20 27 37 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 18 31 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 18 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 20 27 34 45]
#  [ 1 10 18 27 34 45]
#  [ 1 10 13 31 34 45]
#  [ 1 10 20 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 12 13 23 40 44]
#  [ 1 12 13 33 40 44]
#  [ 1 10 13 33 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 20 27 34 45]
#  [ 1 10 13 31 34 45]
#  [ 1 10 18 27 34 45]
#  [ 1 10 13 31 34 45]
#  [ 1 10 13 27 34 45]
#  [ 3 12 16 23 39 44]
#  [ 1 10 18 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 18 31 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 13 31 34 45]
#  [ 1 10 18 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 12 13 33 40 44]
#  [ 1 10 18 27 34 45]
#  [ 1 12 20 27 39 45]
#  [ 1 12 13 33 34 45]
#  [ 1 12 13 33 40 44]
#  [ 1 10 13 27 34 45]
#  [ 1 10 18 27 34 45]
#  [ 1 10 18 31 34 45]
#  [ 1 10 18 31 34 45]
#  [ 1 10 18 27 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 18 31 34 45]
#  [ 1 10 18 27 34 45]
#  [ 1 10 18 27 34 45]
#  [ 1 10 18 31 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 18 27 34 45]
#  [ 1  8 13 33 34 45]
#  [ 1 10 13 27 34 45]
#  [ 1 10 13 31 34 45]]

# %%
# 평가용 함수 - 분류
from sklearn.metrics import mean_squared_error

print(np.sqrt(mean_squared_error(yval, pred1)))
print(np.sqrt(mean_squared_error(yval, pred4)))
print(np.sqrt(mean_squared_error(yval, pred5)))
# Out:
# 7.863802765799377
# 9.066338006520871
# 7.996211224035664

# %%
# from sklearn.ensemble import RandomForestRegressor

# model = RandomForestRegressor(random_state = 202307,
#                               max_depth = 3,
#                               n_estimators= 5)
# model.fit(Xtr, ytr)

# rpred = model.predict(Xval)
# rpred

# %%
# from sklearn.metrics import mean_squared_error

# print(np.sqrt(mean_squared_error(yval, rpred)))

# %%
# from sklearn.ensemble import RandomForestClassifier

# model2 = RandomForestClassifier(random_state = 202307,
#                               max_depth = 5,
#                               n_estimators= 100)
# model2.fit(Xtr, ytr)

# rpred2 = model2.predict(Xval)
# rpred2

# %%
# from sklearn.metrics import roc_auc_score

# print(roc_auc_score(yval, rpred2))

# %%
pred = model1.predict(Xtest)
pred
# Out:
# array([[ 1, 11, 13, 26, 38, 45],
#        [ 1, 11, 13, 26, 38, 45],
#        [ 1, 11, 13, 26, 38, 45],
#        [ 1, 11, 13, 26, 38, 45],
#        [ 1, 11, 13, 26, 38, 45],
#        [ 1, 11, 13, 26, 38, 45],
#        [ 1, 11, 13, 26, 38, 45]])

# %%
from sklearn.neighbors import KNeighborsClassifier

model11 = KNeighborsClassifier(n_neighbors = 300,
                              leaf_size = 7)

model11.fit(Xtrain, ytrain)

kpred = model11.predict(Xtest)
kpred
# Out:
# array([[ 4, 11, 13, 26, 38, 45],
#        [ 4, 11, 13, 26, 38, 45],
#        [ 4, 11, 13, 26, 38, 45],
#        [ 1, 11, 13, 26, 38, 45],
#        [ 1, 11, 13, 26, 38, 45],
#        [ 4, 11, 13, 26, 38, 45],
#        [ 4, 11, 13, 26, 38, 45]])

# %%
predi = model4.predict(Xtest)
predi
# Out:
# array([[10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41]])

# %%
from sklearn.tree import DecisionTreeClassifier

model44 = DecisionTreeClassifier(random_state = 202311,
                                max_depth = 50)
model44.fit(Xtrain, ytrain)

dpred = model44.predict(Xtest)
dpred
# Out:
# array([[11, 12, 18, 21, 31, 38],
#        [11, 12, 18, 21, 31, 38],
#        [11, 12, 18, 21, 31, 38],
#        [11, 12, 18, 21, 31, 38],
#        [11, 12, 18, 21, 31, 38],
#        [11, 12, 18, 21, 31, 38],
#        [11, 12, 18, 21, 31, 38]])

# %%
predo = model5.predict(Xtest)
predo
# Out:
# array([[ 4, 10, 12, 22, 24, 33],
#        [ 4, 10, 12, 22, 24, 33],
#        [ 4, 10, 12, 22, 24, 33],
#        [ 4, 10, 12, 22, 24, 33],
#        [ 4, 10, 12, 22, 24, 33],
#        [ 4, 10, 12, 22, 24, 33],
#        [ 4, 10, 12, 22, 24, 33]])

# %%
from sklearn.ensemble import RandomForestRegressor

model55 = RandomForestClassifier(random_state = 202311,
                                max_depth = 2,
                                n_estimators= 60)
model55.fit(Xtrain, ytrain)

rpred = model55.predict(Xtest)
rpred
# Out:
# array([[ 4, 12, 18, 22, 28, 33],
#        [ 4, 12, 18, 22, 28, 33],
#        [ 4, 12, 18, 22, 28, 33],
#        [ 4, 12, 18, 22, 28, 33],
#        [ 4, 12, 18, 22, 28, 33],
#        [ 4, 12, 18, 22, 28, 33],
#        [ 4, 12, 18, 22, 28, 33]])
