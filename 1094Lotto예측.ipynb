# %% [markdown]
# <a href="https://colab.research.google.com/github/YonggunJung/colab/blob/main/1094Lotto%EC%98%88%EC%B8%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/로또/data/lotto.csv')
df
# Out:
#        1   2   3   4   5   6     일     이     삼     사     오     육
# 0      4   7  17  18  38  44   8.0  12.0  13.0  29.0  33.0  42.0
# 1      8  12  13  29  33  42   3.0   7.0  14.0  15.0  22.0  38.0
# 2      3   7  14  15  22  38  21.0  26.0  27.0  32.0  34.0  42.0
# 3     21  26  27  32  34  42   1.0   9.0  16.0  23.0  24.0  38.0
# 4      1   9  16  23  24  38  13.0  16.0  23.0  31.0  36.0  44.0
# ...   ..  ..  ..  ..  ..  ..   ...   ...   ...   ...   ...   ...
# 1088   4  18  31  37  42  43  12.0  19.0  21.0  29.0  40.0  45.0
# 1089  12  19  21  29  40  45   6.0  20.0  23.0  24.0  28.0  30.0
# 1090   6  20  23  24  28  30   7.0  18.0  19.0  26.0  33.0  45.0
# 1091   7  18  19  26  33  45  10.0  17.0  22.0  30.0  35.0  43.0
# 1092  10  17  22  30  35  43   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1093 rows x 12 columns]

# %%
Xtrain = df.drop(['일', '이', '삼', '사','오', '육'], axis = 1)
Xtrain
# Out:
#        1   2   3   4   5   6
# 0      4   7  17  18  38  44
# 1      8  12  13  29  33  42
# 2      3   7  14  15  22  38
# 3     21  26  27  32  34  42
# 4      1   9  16  23  24  38
# ...   ..  ..  ..  ..  ..  ..
# 1088   4  18  31  37  42  43
# 1089  12  19  21  29  40  45
# 1090   6  20  23  24  28  30
# 1091   7  18  19  26  33  45
# 1092  10  17  22  30  35  43
#
# [1093 rows x 6 columns]

# %%
Xtest = Xtrain.loc[1090]
Xtest
# Out:
# 1     6
# 2    20
# 3    23
# 4    24
# 5    28
# 6    30
# Name: 1090, dtype: int64

# %%
Xtrain.drop(1090, inplace = True)
Xtrain
# Out:
#        1   2   3   4   5   6
# 0      4   7  17  18  38  44
# 1      8  12  13  29  33  42
# 2      3   7  14  15  22  38
# 3     21  26  27  32  34  42
# 4      1   9  16  23  24  38
# ...   ..  ..  ..  ..  ..  ..
# 1087  11  21  22  30  39  44
# 1088   4  18  31  37  42  43
# 1089  12  19  21  29  40  45
# 1091   7  18  19  26  33  45
# 1092  10  17  22  30  35  43
#
# [1092 rows x 6 columns]

# %%
ytrain = df.drop(['1', '2', '3', '4','5', '6'], axis = 1)
ytrain
# Out:
#          일     이     삼     사     오     육
# 0      8.0  12.0  13.0  29.0  33.0  42.0
# 1      3.0   7.0  14.0  15.0  22.0  38.0
# 2     21.0  26.0  27.0  32.0  34.0  42.0
# 3      1.0   9.0  16.0  23.0  24.0  38.0
# 4     13.0  16.0  23.0  31.0  36.0  44.0
# ...    ...   ...   ...   ...   ...   ...
# 1088  12.0  19.0  21.0  29.0  40.0  45.0
# 1089   6.0  20.0  23.0  24.0  28.0  30.0
# 1090   7.0  18.0  19.0  26.0  33.0  45.0
# 1091  10.0  17.0  22.0  30.0  35.0  43.0
# 1092   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1093 rows x 6 columns]

# %%
ytrain.dropna(inplace = True)
ytrain
# Out:
#          일     이     삼     사     오     육
# 0      8.0  12.0  13.0  29.0  33.0  42.0
# 1      3.0   7.0  14.0  15.0  22.0  38.0
# 2     21.0  26.0  27.0  32.0  34.0  42.0
# 3      1.0   9.0  16.0  23.0  24.0  38.0
# 4     13.0  16.0  23.0  31.0  36.0  44.0
# ...    ...   ...   ...   ...   ...   ...
# 1087   4.0  18.0  31.0  37.0  42.0  43.0
# 1088  12.0  19.0  21.0  29.0  40.0  45.0
# 1089   6.0  20.0  23.0  24.0  28.0  30.0
# 1090   7.0  18.0  19.0  26.0  33.0  45.0
# 1091  10.0  17.0  22.0  30.0  35.0  43.0
#
# [1092 rows x 6 columns]

# %%
ytrain =ytrain.astype(int)
ytrain
# Out:
#        일   이   삼   사   오   육
# 0      8  12  13  29  33  42
# 1      3   7  14  15  22  38
# 2     21  26  27  32  34  42
# 3      1   9  16  23  24  38
# 4     13  16  23  31  36  44
# ...   ..  ..  ..  ..  ..  ..
# 1087   4  18  31  37  42  43
# 1088  12  19  21  29  40  45
# 1089   6  20  23  24  28  30
# 1090   7  18  19  26  33  45
# 1091  10  17  22  30  35  43
#
# [1092 rows x 6 columns]

# %%
from pandas import get_dummies

Xtrain = pd.get_dummies(Xtrain)
Xtest = pd.get_dummies(Xtest)
Xtest
# Out:
#    6   20  23  24  28  30
# 1   1   0   0   0   0   0
# 2   0   1   0   0   0   0
# 3   0   0   1   0   0   0
# 4   0   0   0   1   0   0
# 5   0   0   0   0   1   0
# 6   0   0   0   0   0   1

# %%
from sklearn.model_selection import train_test_split

Xtr, Xval, ytr, yval = train_test_split(Xtrain, ytrain,
                                        test_size = 0.1,
                                        random_state = 202311)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedGroupKFold
kfold = KFold(n_splits = 10, shuffle = True, random_state = 202311)

# %%
# !pip install KNN
# !pip install SVC
# !pip install decisiontree
# !pip install voting
# Out:
# Collecting KNN
#   Downloading KNN-1.0.0.tar.gz (2.4 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: KNN
#   Building wheel for KNN (setup.py) ... done
#   Created wheel for KNN: filename=KNN-1.0.0-py3-none-any.whl size=3112 sha256=98598ccba038ae63b48b3ce463157be518a21681481f8493afbd160632009c17
#   Stored in directory: /root/.cache/pip/wheels/db/f0/9c/9da3fdf7ad3d19587a688434d71dbf38ced30bde9fb2975ff7
# Successfully built KNN
# Installing collected packages: KNN
# Successfully installed KNN-1.0.0
# Collecting SVC
#   Downloading SVC-0.1.tar.gz (1.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: xlrd>=0.9.3 in /usr/local/lib/python3.10/dist-packages (from SVC) (2.0.1)
# Building wheels for collected packages: SVC
#   Building wheel for SVC (setup.py) ... done
#   Created wheel for SVC: filename=SVC-0.1-py3-none-any.whl size=1870 sha256=586c71691b00526e1f65a5bafa2c56bd588df7969fe66947101ddd2fdb6c5dce
#   Stored in directory: /root/.cache/pip/wheels/88/51/46/316b33cfa9e39d0749762daa17b6a8646e3050079185747370
# Successfully built SVC
# Installing collected packages: SVC
# Successfully installed SVC-0.1
# Collecting decisiontree
#   Downloading DecisionTree-3.4.3.tar.gz (335 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 335.3/335.3 kB 5.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: decisiontree
#   Building wheel for decisiontree (setup.py) ... done
#   Created wheel for decisiontree: filename=DecisionTree-3.4.3-py3-none-any.whl size=81844 sha256=4fe490dc7c068918cfed98af722b295a0fcaf8feee3357dcd802e28aabeb5680
#   Stored in directory: /root/.cache/pip/wheels/59/d4/29/d88ed8e92d4c96a49d195c034b7f0e7ce74b10531fbfd98555
# Successfully built decisiontree
# Installing collected packages: decisiontree
# Successfully installed decisiontree-3.4.3
# Collecting voting
#   Downloading voting-0.1.3-py2.py3-none-any.whl (8.0 kB)
# Installing collected packages: voting
# Successfully installed voting-0.1.3

# %%
# 머신러닝 알고리즘 분류
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import VotingClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

model1 = KNeighborsClassifier(n_neighbors = 350,
                              leaf_size = 6)
model2 = LogisticRegression(random_state = 202311)
model3 = SVC(random_state = 202311, probability = True)
model4 = DecisionTreeClassifier(random_state = 202311,
                                max_depth = 50)
model5 = RandomForestClassifier(random_state = 202311,
                                max_depth = 2,
                                n_estimators= 60)
model6 = AdaBoostClassifier(random_state = 202309)
model7 = GradientBoostingClassifier(random_state = 202311)
model8 = LGBMClassifier(random_state = 202311)
model9 = XGBClassifier(random_state = 202311, silent = True, verbosity = 0)

# %%
model1.fit(Xtr, ytr)
# model2.fit(Xtr, ytr)
# model3.fit(Xtr, ytr)
model4.fit(Xtr, ytr)
model5.fit(Xtr, ytr)
# model6.fit(Xtr, ytr)
# model7.fit(Xtr, ytr)
# model8.fit(Xtr, ytr)
# model9.fit(Xtr, ytr)
# model10.fit(Xtr, ytr)
# model11.fit(Xtr, ytr)

pred1 = model1.predict(Xval)
# pred2 = model2.predict(Xval)
# pred3 = model3.predict(Xval)
pred4 = model4.predict(Xval)
pred5 = model5.predict(Xval)
# pred6 = model6.predict(Xval)
# pred7 = model7.predict(Xval)
# pred8 = model8.predict(Xval)
# pred9 = model9.predict(Xval)
# pred10 = model10.predict(Xval)
# pred11 = model11.predict(Xval)

print('KNN : ', pred1)
# print('LogisticRegression' + pred2)
# print('SVM' + pred3)
print('DecisionTree : ', + pred4)
print('RandomForest : ', + pred5)
# print('AdaBoost' + pred6)
# print('GradientBoost' + pred7)
# print('LGBM' + pred8)
# print('XGBoost' + pred9)
# print('Voting(hard)' + pred10)
# print('Voting(soft)' + pred11)
# Out:
# KNN :  [[ 1 10 13 26 39 44]
#  [ 1  8 20 31 34 45]
#  [ 1 10 13 26 34 45]
#  [ 1 10 13 26 39 45]
#  [ 1  8 14 27 34 45]
#  [ 2  8 20 31 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 15 30 34 44]
#  [ 1  7 15 26 34 44]
#  [ 1 10 13 26 39 45]
#  [ 1  8 13 24 34 44]
#  [ 1 10 15 26 34 44]
#  [ 1  8 14 32 34 44]
#  [ 1  7 15 27 34 45]
#  [ 1  8 15 31 34 45]
#  [ 1  8 20 21 34 45]
#  [ 1  8 20 30 34 44]
#  [ 1 10 13 26 39 45]
#  [ 1  8 13 21 34 45]
#  [ 1  8 15 24 34 45]
#  [ 1  8 15 24 34 44]
#  [ 1  8 20 31 34 45]
#  [ 1  8 13 31 34 44]
#  [ 1 10 20 21 34 45]
#  [ 1  7 15 26 34 45]
#  [ 1  9 15 27 34 44]
#  [ 1 14 20 24 34 45]
#  [ 1  8 18 31 34 45]
#  [ 2  7 14 32 34 45]
#  [ 2 11 23 27 34 43]
#  [ 1  8 14 30 34 44]
#  [ 1  7 14 27 34 44]
#  [ 2  8 20 31 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  7 15 32 34 45]
#  [ 1 11 15 27 34 44]
#  [ 2  8 20 31 34 45]
#  [ 1 11 13 26 34 45]
#  [ 1 10 20 21 34 45]
#  [ 1  8 20 30 34 45]
#  [ 1  8 15 30 34 44]
#  [ 1  7 15 32 34 44]
#  [ 1  8 20 21 34 45]
#  [ 1  9 15 26 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 15 27 34 45]
#  [ 1  7 14 27 34 44]
#  [ 1 11 15 31 34 44]
#  [ 2  8 20 31 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1 11 15 26 34 44]
#  [ 1  7 18 26 34 45]
#  [ 1  8 15 27 34 45]
#  [ 2  8 20 31 37 45]
#  [ 1  7 15 27 34 44]
#  [ 1  7 15 32 34 44]
#  [ 1  7 15 26 39 45]
#  [ 1 11 13 32 34 44]
#  [ 1 11 22 31 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  7 15 27 34 44]
#  [ 1 11 13 26 34 44]
#  [ 1  7 15 27 38 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 14 27 34 44]
#  [ 1  8 18 21 34 45]
#  [ 1 11 15 27 34 44]
#  [ 1  8 18 28 34 45]
#  [ 1  8 15 31 34 45]
#  [ 1  9 15 27 34 43]
#  [ 1 10 13 26 39 45]
#  [ 1  7 15 32 34 45]
#  [ 2  8 15 31 34 44]
#  [ 1  8 15 27 34 44]
#  [ 1  8 14 31 34 45]
#  [ 1  7 13 32 33 45]
#  [ 1  8 14 32 34 45]
#  [ 1  8 20 31 34 44]
#  [ 2 11 13 26 34 44]
#  [ 1  8 13 33 34 44]
#  [ 1  8 20 31 34 45]
#  [ 1 11 15 27 34 44]
#  [ 1  8 13 31 34 45]
#  [ 1  9 15 27 34 44]
#  [ 1  8 15 32 34 44]
#  [ 1  8 13 33 34 45]
#  [ 1  8 15 27 34 44]
#  [ 1  7 15 26 34 45]
#  [ 1 14 15 32 34 44]
#  [ 1  8 20 21 37 45]
#  [ 1  8 20 28 34 45]
#  [ 1  8 15 27 34 44]
#  [ 2  8 13 23 34 44]
#  [ 1 10 13 26 39 45]
#  [ 1  7 19 26 34 44]
#  [ 1  8 15 30 34 44]
#  [ 1 10 19 24 34 45]
#  [ 1  8 14 27 34 44]
#  [ 1 10 13 26 39 45]
#  [ 1  7 14 27 34 44]
#  [ 1  8 20 33 34 44]
#  [ 1 11 15 26 34 45]
#  [ 1 11 15 27 34 44]
#  [ 1  8 20 31 34 45]
#  [ 1 11 15 31 34 44]
#  [ 1 11 13 26 39 45]
#  [ 1  7 22 27 34 44]
#  [ 2  8 20 31 34 45]
#  [ 1  8 20 32 34 45]
#  [ 1 10 13 31 34 43]]
# DecisionTree :  [[ 1  9 12 23 39 43]
#  [12 16 19 22 37 40]
#  [25 27 29 36 38 40]
#  [ 6 10 17 30 37 38]
#  [ 1 18 30 41 42 43]
#  [ 1  5  6 14 20 39]
#  [ 6 15 17 18 35 40]
#  [13 14 24 32 39 41]
#  [ 1  3 17 20 31 44]
#  [ 7 22 29 33 34 35]
#  [ 7 15 20 25 33 43]
#  [ 4  5 12 14 32 42]
#  [11 23 25 30 32 40]
#  [ 7 11 13 17 18 29]
#  [ 3  6  9 18 22 35]
#  [13 14 18 22 35 39]
#  [ 5  7  8 15 30 43]
#  [ 9 17 19 30 35 42]
#  [11 21 24 30 39 45]
#  [ 9 18 32 33 37 44]
#  [ 7  8 24 34 36 41]
#  [ 1  6  9 16 17 28]
#  [ 3  4  9 24 25 33]
#  [21 24 27 29 43 44]
#  [ 6 11 16 19 21 32]
#  [ 7  9 22 27 37 42]
#  [ 1  2 11 21 30 35]
#  [13 18 30 31 38 41]
#  [14 23 30 32 34 38]
#  [ 8 22 35 38 39 41]
#  [15 20 23 26 39 44]
#  [ 8 13 14 30 38 39]
#  [ 3 10 16 19 31 39]
#  [12 15 19 26 40 43]
#  [ 4 11 20 26 35 37]
#  [ 6 11 16 19 21 32]
#  [ 6 16 37 38 41 45]
#  [19 23 30 37 43 45]
#  [ 1  3 12 14 16 43]
#  [ 1 14 15 24 40 41]
#  [ 5 32 34 40 41 45]
#  [ 2 13 34 38 42 45]
#  [ 5 16 21 23 24 30]
#  [13 15 21 29 39 43]
#  [10 11 15 25 35 41]
#  [ 1 18 30 41 42 43]
#  [ 8 14 18 30 31 44]
#  [14 15 19 30 38 43]
#  [ 7 11 13 33 37 43]
#  [ 5 17 26 27 35 38]
#  [ 1  8  9 17 29 32]
#  [ 6 12 17 18 31 32]
#  [12 18 30 39 41 42]
#  [ 3 15 20 22 24 41]
#  [ 6  7 11 17 33 44]
#  [ 7 12 15 24 25 43]
#  [ 7 20 22 25 38 40]
#  [11 18 26 27 40 41]
#  [ 1  5 21 25 38 41]
#  [ 1  5  6 14 20 39]
#  [ 7 10 16 28 41 42]
#  [15 17 25 37 42 43]
#  [ 8 17 21 24 27 31]
#  [ 3 22 25 29 32 44]
#  [ 8 13 26 28 32 34]
#  [ 1  4 10 12 28 45]
#  [ 3 16 22 37 38 44]
#  [12 13 17 22 25 33]
#  [ 1  3 24 27 39 45]
#  [ 2  3  4  5 20 24]
#  [ 3  4 10 17 19 22]
#  [21 22 26 27 31 37]
#  [11 18 21 26 38 43]
#  [11 12 14 15 18 39]
#  [ 7  9 12 27 39 43]
#  [ 2 10 12 31 33 42]
#  [ 2 13 25 28 29 36]
#  [ 1  2 10 25 26 44]
#  [ 9 16 28 40 41 43]
#  [ 4 10 19 29 32 42]
#  [ 4  7 12 14 22 33]
#  [22 23 25 37 38 42]
#  [ 3 10 16 19 31 39]
#  [ 2  3 26 33 34 43]
#  [ 3 12 18 32 40 43]
#  [ 3  8 27 31 41 44]
#  [ 6  9 21 31 32 40]
#  [ 5  9 12 20 21 26]
#  [ 4  7 15 18 23 26]
#  [ 2  8 23 26 27 44]
#  [12 25 29 35 42 43]
#  [ 1  6 11 28 34 42]
#  [ 1  7 22 33 37 40]
#  [13 17 18 20 42 45]
#  [ 4  9 23 26 29 33]
#  [ 2  5 10 18 31 32]
#  [14 21 29 31 32 37]
#  [17 22 26 27 36 39]
#  [ 5 20 23 27 35 40]
#  [ 2  5 10 18 31 32]
#  [ 3  4 16 20 28 44]
#  [ 9 15 29 34 37 39]
#  [ 8  9 18 21 28 40]
#  [ 3 22 25 29 32 44]
#  [ 2  5 22 32 34 45]
#  [ 4  5 12 14 32 42]
#  [ 6 31 35 38 39 44]
#  [ 3 22 25 29 32 44]
#  [ 2 12 30 31 39 43]
#  [11 20 29 31 33 42]]
# RandomForest :  [[ 1 11 13 26 34 45]
#  [ 1  8 13 31 34 45]
#  [ 1 10 13 26 37 45]
#  [ 1 10 18 26 34 45]
#  [ 1  7 13 31 34 45]
#  [ 1  7 13 31 34 45]
#  [ 1 10 18 31 34 45]
#  [ 1  7 18 26 34 45]
#  [ 1  7 18 26 34 45]
#  [ 1 14 17 33 36 45]
#  [ 1  7 13 31 34 45]
#  [ 1  7 18 26 34 45]
#  [ 1 11 18 26 34 45]
#  [ 1 10 13 26 34 45]
#  [ 1 10 15 26 34 45]
#  [ 1 11 20 26 37 45]
#  [ 1  7 18 26 34 45]
#  [ 1 11 13 26 39 45]
#  [ 1  7 13 33 39 45]
#  [ 1 11 18 31 34 45]
#  [ 1 10 18 26 34 45]
#  [ 1  7 18 26 34 45]
#  [ 1  7 13 31 34 45]
#  [ 1 10 18 31 37 45]
#  [ 1  7 13 26 34 45]
#  [ 1  7 18 26 34 45]
#  [ 1 10 18 26 34 45]
#  [ 1  7 13 33 34 45]
#  [ 1 11 13 26 34 45]
#  [ 1  7 13 26 34 45]
#  [ 1  7 18 26 34 45]
#  [ 1 10 18 27 34 44]
#  [ 1 10 18 31 34 45]
#  [ 1 10 19 29 34 45]
#  [ 1  7 18 26 34 45]
#  [ 1  7 18 26 34 45]
#  [ 1  8 18 31 34 45]
#  [ 1  7 13 25 34 45]
#  [ 1  7 19 31 39 45]
#  [ 1 10 13 31 34 45]
#  [ 1  7 18 26 34 45]
#  [ 1  7 18 26 34 45]
#  [ 1 15 18 30 37 45]
#  [ 1 10 18 26 34 45]
#  [ 1 10 18 26 34 45]
#  [ 1 10 13 31 34 45]
#  [ 1 11 18 26 34 45]
#  [ 1  7 18 26 34 45]
#  [ 1  7 18 31 34 45]
#  [ 1  7 20 26 37 45]
#  [ 1  7 13 25 34 45]
#  [ 1 10 18 21 34 45]
#  [ 1 10 13 31 34 45]
#  [ 1  7 18 31 34 45]
#  [ 1  7 18 26 34 45]
#  [ 1 10 13 26 34 45]
#  [ 1  7 13 26 34 45]
#  [ 1  7 13 26 34 45]
#  [ 1 10 18 26 34 45]
#  [ 1 10 13 31 34 45]
#  [ 1  7 18 26 34 45]
#  [ 1  7 13 26 34 45]
#  [ 1 10 18 31 34 44]
#  [ 1 10 18 31 34 45]
#  [ 1 10 13 31 34 45]
#  [ 1  7 20 26 37 45]
#  [ 1  7 13 26 34 45]
#  [ 1 10 18 31 34 45]
#  [ 1  7 13 31 34 45]
#  [ 1  7 13 26 34 45]
#  [ 1 11 13 26 39 45]
#  [ 1 11 18 26 34 45]
#  [ 1 10 13 31 34 45]
#  [ 1 10 18 31 34 45]
#  [ 1 10 18 31 34 45]
#  [ 1  7 18 26 34 45]
#  [ 1  7 18 31 34 45]
#  [ 1  7 18 26 34 45]
#  [ 1 11 13 26 34 45]
#  [ 1 10 19 31 34 45]
#  [ 1 10 15 31 34 45]
#  [ 1 11 18 27 34 45]
#  [ 1 10 18 31 34 45]
#  [ 1 10 18 26 34 45]
#  [ 1  7 18 26 34 45]
#  [ 1  8 19 26 34 45]
#  [ 1 10 13 31 34 45]
#  [ 1  7 13 26 34 45]
#  [ 1  7 18 26 34 45]
#  [ 1 15 18 30 39 45]
#  [ 1 11 19 31 34 45]
#  [ 1  7 18 26 34 45]
#  [ 1  7 13 31 34 45]
#  [ 1 11 13 26 39 45]
#  [ 1  7 13 26 34 45]
#  [ 1 10 15 26 34 45]
#  [ 1  7 18 26 34 45]
#  [ 1  7 18 31 34 45]
#  [ 1 11 13 26 34 45]
#  [ 1 10 13 31 34 45]
#  [ 1  8 18 31 34 45]
#  [ 1 13 20 26 34 45]
#  [ 1  7 18 26 34 45]
#  [ 1 10 18 31 34 45]
#  [ 1  7 13 26 34 45]
#  [ 1  7 13 26 34 45]
#  [ 1 10 15 26 34 45]
#  [ 1 11 18 31 34 45]
#  [ 1  7 18 26 34 45]
#  [ 1 10 18 31 34 45]]

# %%
# 평가용 함수 - 분류
from sklearn.metrics import mean_squared_error

print(np.sqrt(mean_squared_error(yval, pred1)))
print(np.sqrt(mean_squared_error(yval, pred4)))
print(np.sqrt(mean_squared_error(yval, pred5)))
# Out:
# 7.950795652961502
# 9.66350523016019
# 7.9981058363650686

# %%
pred = model1.predict(Xtest)
pred
# Out:
# array([[ 1, 10, 13, 26, 39, 45],
#        [ 1, 10, 13, 26, 39, 45],
#        [ 1, 10, 13, 26, 39, 45],
#        [ 1, 10, 13, 26, 39, 45],
#        [ 1, 10, 13, 26, 39, 45],
#        [ 1, 10, 13, 26, 39, 45]])

# %%
from sklearn.neighbors import KNeighborsClassifier

model11 = KNeighborsClassifier(n_neighbors = 350,
                              leaf_size = 6)

model11.fit(Xtrain, ytrain)

kpred = model11.predict(Xtest)
kpred
# Out:
# array([[ 1, 10, 13, 26, 39, 45],
#        [ 1, 10, 13, 26, 39, 45],
#        [ 1, 10, 13, 26, 39, 45],
#        [ 1, 10, 13, 26, 39, 45],
#        [ 1, 10, 13, 26, 39, 45],
#        [ 1, 10, 13, 26, 39, 45]])

# %%
predi = model4.predict(Xtest)
predi
# Out:
# array([[10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41]])

# %%
from sklearn.tree import DecisionTreeClassifier

model44 = DecisionTreeClassifier(random_state = 202311,
                                max_depth = 50)
model44.fit(Xtrain, ytrain)

dpred = model44.predict(Xtest)
dpred
# Out:
# array([[10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41],
#        [10, 15, 18, 21, 34, 41]])

# %%
predo = model5.predict(Xtest)
predo
# Out:
# array([[ 1, 12, 18, 21, 36, 38],
#        [ 1, 12, 18, 21, 36, 38],
#        [ 1, 12, 18, 21, 36, 38],
#        [ 1, 12, 18, 21, 36, 38],
#        [ 1, 12, 18, 21, 36, 38],
#        [ 1, 12, 18, 21, 36, 38]])

# %%
from sklearn.ensemble import RandomForestRegressor

model55 = RandomForestClassifier(random_state = 202311,
                                max_depth = 2,
                                n_estimators= 60)
model55.fit(Xtrain, ytrain)

rpred = model55.predict(Xtest)
rpred
# Out:
# array([[ 4, 12, 18, 21, 31, 38],
#        [ 4, 12, 18, 21, 31, 38],
#        [ 4, 12, 18, 21, 31, 38],
#        [ 4, 12, 18, 21, 31, 38],
#        [ 4, 12, 18, 21, 31, 38],
#        [ 4, 12, 18, 21, 31, 38]])

# %%
# from sklearn.metrics import mean_squared_error

# print(np.sqrt(mean_squared_error(yval, rpred)))

# %%
# from sklearn.ensemble import RandomForestClassifier

# model2 = RandomForestClassifier(random_state = 202307,
#                               max_depth = 5,
#                               n_estimators= 100)
# model2.fit(Xtr, ytr)

# rpred2 = model2.predict(Xval)
# rpred2

# %%
# from sklearn.metrics import roc_auc_score

# print(roc_auc_score(yval, rpred2))
