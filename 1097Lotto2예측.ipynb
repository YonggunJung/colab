# %% [markdown]
# <a href="https://colab.research.google.com/github/YonggunJung/colab/blob/main/1097Lotto2%EC%98%88%EC%B8%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/로또/data/lotto2.csv')
df
# Out:
#        1   2   3   4   5   6  보너스     일     이     삼     사     오     육
# 0     11  21  22  30  39  44   31  13.0  14.0  18.0  21.0  34.0  44.0
# 1     13  14  18  21  34  44   16  11.0  16.0  25.0  27.0  35.0  36.0
# 2     11  16  25  27  35  36   37   4.0   7.0  17.0  18.0  38.0  44.0
# 3      4   7  17  18  38  44   36   8.0  12.0  13.0  29.0  33.0  42.0
# 4      8  12  13  29  33  42    5   3.0   7.0  14.0  15.0  22.0  38.0
# ...   ..  ..  ..  ..  ..  ..  ...   ...   ...   ...   ...   ...   ...
# 1091   7  18  19  26  33  45   37  10.0  17.0  22.0  30.0  35.0  43.0
# 1092  10  17  22  30  35  43   44   6.0   7.0  15.0  22.0  26.0  40.0
# 1093   6   7  15  22  26  40   41   8.0  14.0  28.0  29.0  34.0  40.0
# 1094   8  14  28  29  34  40   12   1.0  12.0  16.0  19.0  23.0  43.0
# 1095   1  12  16  19  23  43   34   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1096 rows x 13 columns]

# %%
Xtrain = df.drop(['일', '이', '삼', '사','오', '육'], axis = 1)
Xtrain
# Out:
#        1   2   3   4   5   6  보너스
# 0     11  21  22  30  39  44   31
# 1     13  14  18  21  34  44   16
# 2     11  16  25  27  35  36   37
# 3      4   7  17  18  38  44   36
# 4      8  12  13  29  33  42    5
# ...   ..  ..  ..  ..  ..  ..  ...
# 1091   7  18  19  26  33  45   37
# 1092  10  17  22  30  35  43   44
# 1093   6   7  15  22  26  40   41
# 1094   8  14  28  29  34  40   12
# 1095   1  12  16  19  23  43   34
#
# [1096 rows x 7 columns]

# %%
Xtest = Xtrain.iloc[Xtrain.index[-1]]
Xtest
# Out:
# 1       1
# 2      12
# 3      16
# 4      19
# 5      23
# 6      43
# 보너스    34
# Name: 1095, dtype: int64

# %%
Xtrain.drop(Xtrain.index[-1], inplace = True)
Xtrain
# Out:
#        1   2   3   4   5   6  보너스
# 0     11  21  22  30  39  44   31
# 1     13  14  18  21  34  44   16
# 2     11  16  25  27  35  36   37
# 3      4   7  17  18  38  44   36
# 4      8  12  13  29  33  42    5
# ...   ..  ..  ..  ..  ..  ..  ...
# 1090   6  20  23  24  28  30   44
# 1091   7  18  19  26  33  45   37
# 1092  10  17  22  30  35  43   44
# 1093   6   7  15  22  26  40   41
# 1094   8  14  28  29  34  40   12
#
# [1095 rows x 7 columns]

# %%
ytrain = df.drop(['1', '2', '3', '4','5', '6', '보너스'], axis = 1)
ytrain
# Out:
#          일     이     삼     사     오     육
# 0     13.0  14.0  18.0  21.0  34.0  44.0
# 1     11.0  16.0  25.0  27.0  35.0  36.0
# 2      4.0   7.0  17.0  18.0  38.0  44.0
# 3      8.0  12.0  13.0  29.0  33.0  42.0
# 4      3.0   7.0  14.0  15.0  22.0  38.0
# ...    ...   ...   ...   ...   ...   ...
# 1091  10.0  17.0  22.0  30.0  35.0  43.0
# 1092   6.0   7.0  15.0  22.0  26.0  40.0
# 1093   8.0  14.0  28.0  29.0  34.0  40.0
# 1094   1.0  12.0  16.0  19.0  23.0  43.0
# 1095   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1096 rows x 6 columns]

# %%
ytrain.dropna(inplace = True)
ytrain
# Out:
#          일     이     삼     사     오     육
# 0     13.0  14.0  18.0  21.0  34.0  44.0
# 1     11.0  16.0  25.0  27.0  35.0  36.0
# 2      4.0   7.0  17.0  18.0  38.0  44.0
# 3      8.0  12.0  13.0  29.0  33.0  42.0
# 4      3.0   7.0  14.0  15.0  22.0  38.0
# ...    ...   ...   ...   ...   ...   ...
# 1090   7.0  18.0  19.0  26.0  33.0  45.0
# 1091  10.0  17.0  22.0  30.0  35.0  43.0
# 1092   6.0   7.0  15.0  22.0  26.0  40.0
# 1093   8.0  14.0  28.0  29.0  34.0  40.0
# 1094   1.0  12.0  16.0  19.0  23.0  43.0
#
# [1095 rows x 6 columns]

# %%
ytrain =ytrain.astype(int)
ytrain
# Out:
#        일   이   삼   사   오   육
# 0     13  14  18  21  34  44
# 1     11  16  25  27  35  36
# 2      4   7  17  18  38  44
# 3      8  12  13  29  33  42
# 4      3   7  14  15  22  38
# ...   ..  ..  ..  ..  ..  ..
# 1090   7  18  19  26  33  45
# 1091  10  17  22  30  35  43
# 1092   6   7  15  22  26  40
# 1093   8  14  28  29  34  40
# 1094   1  12  16  19  23  43
#
# [1095 rows x 6 columns]

# %%
from pandas import get_dummies

Xtrain = pd.get_dummies(Xtrain)
Xtest = pd.get_dummies(Xtest)
Xtest
# Out:
#      1   12  16  19  23  34  43
# 1     1   0   0   0   0   0   0
# 2     0   1   0   0   0   0   0
# 3     0   0   1   0   0   0   0
# 4     0   0   0   1   0   0   0
# 5     0   0   0   0   1   0   0
# 6     0   0   0   0   0   0   1
# 보너스   0   0   0   0   0   1   0

# %%
from sklearn.model_selection import train_test_split

Xtr, Xval, ytr, yval = train_test_split(Xtrain, ytrain,
                                        test_size = 0.1,
                                        random_state = 202309)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedGroupKFold
kfold = KFold(n_splits = 10, shuffle = True, random_state = 202309)

# %%
# !pip install KNN
# !pip install SVC
# !pip install decisiontree
# !pip install voting
# Out:
# Collecting KNN
#   Downloading KNN-1.0.0.tar.gz (2.4 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: KNN
#   Building wheel for KNN (setup.py) ... done
#   Created wheel for KNN: filename=KNN-1.0.0-py3-none-any.whl size=3109 sha256=6696fe00fb75e6b3ed03f6de4722dbe0a62204e85ebf8e2a28075dd01ca6a93e
#   Stored in directory: /root/.cache/pip/wheels/db/f0/9c/9da3fdf7ad3d19587a688434d71dbf38ced30bde9fb2975ff7
# Successfully built KNN
# Installing collected packages: KNN
# Successfully installed KNN-1.0.0
# Collecting SVC
#   Downloading SVC-0.1.tar.gz (1.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: xlrd>=0.9.3 in /usr/local/lib/python3.10/dist-packages (from SVC) (2.0.1)
# Building wheels for collected packages: SVC
#   Building wheel for SVC (setup.py) ... done
#   Created wheel for SVC: filename=SVC-0.1-py3-none-any.whl size=1872 sha256=c6535a55f22c3b59e96f6535f6696619c03113c96c45e093dcc61bc5adf76770
#   Stored in directory: /root/.cache/pip/wheels/88/51/46/316b33cfa9e39d0749762daa17b6a8646e3050079185747370
# Successfully built SVC
# Installing collected packages: SVC
# Successfully installed SVC-0.1
# Collecting decisiontree
#   Downloading DecisionTree-3.4.3.tar.gz (335 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 335.3/335.3 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: decisiontree
#   Building wheel for decisiontree (setup.py) ... done
#   Created wheel for decisiontree: filename=DecisionTree-3.4.3-py3-none-any.whl size=81841 sha256=038c9740c7325fe4a5015e0e2931d5dd439563bd96802c8d19aa65711af51ff1
#   Stored in directory: /root/.cache/pip/wheels/59/d4/29/d88ed8e92d4c96a49d195c034b7f0e7ce74b10531fbfd98555
# Successfully built decisiontree
# Installing collected packages: decisiontree
# Successfully installed decisiontree-3.4.3
# Collecting voting
#   Downloading voting-0.1.3-py2.py3-none-any.whl (8.0 kB)
# Installing collected packages: voting
# Successfully installed voting-0.1.3

# %%
# 머신러닝 알고리즘 분류
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import VotingClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

model1 = KNeighborsClassifier(n_neighbors = 300,
                              leaf_size = 7)
model2 = LogisticRegression(random_state = 202309)
model3 = SVC(random_state = 202309, probability = True)
model4 = DecisionTreeClassifier(random_state = 202309,
                                max_depth = 50)
model5 = RandomForestClassifier(random_state = 202309,
                                max_depth = 2,
                                n_estimators= 60)
model6 = AdaBoostClassifier(random_state = 202309)
model7 = GradientBoostingClassifier(random_state = 202309)
model8 = LGBMClassifier(random_state = 202309)
model9 = XGBClassifier(random_state = 202309, silent = True, verbosity = 0)

# %%
model1.fit(Xtr, ytr)
# model2.fit(Xtr, ytr)
# model3.fit(Xtr, ytr)
model4.fit(Xtr, ytr)
model5.fit(Xtr, ytr)
# model6.fit(Xtr, ytr)
# model7.fit(Xtr, ytr)
# model8.fit(Xtr, ytr)
# model9.fit(Xtr, ytr)
# model10.fit(Xtr, ytr)
# model11.fit(Xtr, ytr)

pred1 = model1.predict(Xval)
# pred2 = model2.predict(Xval)
# pred3 = model3.predict(Xval)
pred4 = model4.predict(Xval)
pred5 = model5.predict(Xval)
# pred6 = model6.predict(Xval)
# pred7 = model7.predict(Xval)
# pred8 = model8.predict(Xval)
# pred9 = model9.predict(Xval)
# pred10 = model10.predict(Xval)
# pred11 = model11.predict(Xval)

print('KNN : ', pred1)
# print('LogisticRegression' + pred2)
# print('SVM' + pred3)
print('DecisionTree : ', + pred4)
print('RandomForest : ', + pred5)
# print('AdaBoost' + pred6)
# print('GradientBoost' + pred7)
# print('LGBM' + pred8)
# print('XGBoost' + pred9)
# print('Voting(hard)' + pred10)
# print('Voting(soft)' + pred11)
# Out:
# KNN :  [[ 1  8 19 31 34 45]
#  [ 1  8 20 33 34 45]
#  [ 1 14 19 21 34 45]
#  [ 1 14 19 30 34 43]
#  [ 1  8 16 23 33 45]
#  [ 1 12 19 27 34 44]
#  [ 2  8 14 27 34 44]
#  [ 2  7 20 27 34 45]
#  [ 1 12 13 27 34 45]
#  [ 1  8 20 26 33 45]
#  [ 1  7 13 27 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  7 18 27 34 45]
#  [ 1  7 13 27 34 45]
#  [ 1 11 15 30 34 43]
#  [ 1 11 16 33 36 45]
#  [ 1  8 19 33 34 45]
#  [ 1  8 20 21 34 45]
#  [ 1  7 18 27 34 45]
#  [ 1  5 14 27 35 45]
#  [ 1  8 16 23 34 45]
#  [ 2 13 20 27 34 45]
#  [ 1 11 16 32 33 45]
#  [ 1 10 20 29 34 45]
#  [ 1 11 16 33 33 45]
#  [ 1 11 16 30 34 45]
#  [ 1  8 16 31 33 45]
#  [ 2 12 13 27 34 45]
#  [ 1 11 16 31 33 45]
#  [ 1 11 16 33 38 45]
#  [ 2  7 19 27 34 45]
#  [ 1  7 18 27 34 45]
#  [ 1  7 18 27 34 45]
#  [ 1 11 16 23 34 45]
#  [ 1 12 19 21 34 45]
#  [ 1  8 19 31 34 45]
#  [ 1  8 20 33 34 45]
#  [ 2  8 20 30 34 45]
#  [ 2  7 20 29 39 45]
#  [ 2  8 20 30 34 45]
#  [ 1 10 18 26 39 45]
#  [ 1 10 18 27 34 45]
#  [ 1  8 19 33 34 44]
#  [ 1  7 18 27 34 45]
#  [ 1 11 16 32 33 45]
#  [ 1 10 13 27 38 45]
#  [ 1  8 19 31 34 45]
#  [ 2 11 13 26 38 45]
#  [ 1 10 20 30 39 45]
#  [ 1  8 20 31 34 45]
#  [ 1 12 20 27 39 45]
#  [ 1  7 18 27 34 45]
#  [ 1 12 13 26 39 45]
#  [ 1  8 20 31 34 43]
#  [ 2 11 20 30 34 43]
#  [ 1 10 19 27 39 45]
#  [ 1  7 13 27 34 45]
#  [ 1  7 18 27 34 45]
#  [ 1 11 18 27 38 45]
#  [ 2  7 20 29 34 45]
#  [ 1  7 18 27 34 45]
#  [ 1 11 16 33 38 45]
#  [ 1 14 20 30 39 45]
#  [ 1  8 19 33 34 45]
#  [ 1 13 18 27 39 45]
#  [ 1 11 16 33 33 45]
#  [ 1  7 18 27 34 45]
#  [ 1 12 20 21 39 45]
#  [ 1  7 20 27 34 45]
#  [ 2 14 20 30 34 45]
#  [ 1 11 16 23 34 45]
#  [ 1  8 20 27 34 43]
#  [ 1  8 20 33 34 45]
#  [ 1 11 11 27 33 43]
#  [ 1 10 18 27 34 45]
#  [ 1 12 19 21 39 45]
#  [ 1  7 18 27 34 45]
#  [ 2  7 20 27 39 45]
#  [ 1  7 18 27 34 45]
#  [ 1  8 20 33 34 45]
#  [ 1 10 14 27 34 45]
#  [ 1  8 15 33 33 45]
#  [ 1 10 19 27 34 45]
#  [ 1 11 16 31 38 45]
#  [ 2  8 20 27 34 43]
#  [ 2  7 20 27 34 45]
#  [ 1 14 20 30 34 45]
#  [ 1 14 20 30 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1 12 18 27 34 45]
#  [ 1 12 19 21 34 45]
#  [ 1 11 16 33 34 45]
#  [ 2  7 18 27 34 45]
#  [ 1  8 13 33 34 45]
#  [ 1 11 16 31 38 45]
#  [ 1  8 16 33 33 45]
#  [ 1  8 16 33 38 45]
#  [ 1 11 16 33 38 45]
#  [ 1 10 18 26 34 45]
#  [ 1 14 20 35 34 45]
#  [ 1 11 16 33 34 45]
#  [ 2 14 20 30 34 45]
#  [ 2 14 20 27 39 45]
#  [ 2 14 20 30 34 45]
#  [ 1 11 16 33 34 45]
#  [ 1  8 19 30 34 45]
#  [ 1 14 20 30 34 43]
#  [ 1 11 16 27 38 45]
#  [ 1  8 20 23 34 45]
#  [ 2 14 20 27 34 45]]
# DecisionTree :  [[ 6  9 11 22 24 30]
#  [21 26 30 32 33 35]
#  [ 5  7 12 13 18 35]
#  [ 6 12 20 26 29 38]
#  [ 2  6 12 31 33 40]
#  [ 1  4  8 23 33 42]
#  [ 1  4  8 13 37 39]
#  [20 31 32 40 41 45]
#  [17 20 30 31 33 45]
#  [ 2 25 28 30 33 45]
#  [ 5 25 27 29 34 36]
#  [ 9 12 27 36 39 45]
#  [ 1  6 17 22 28 45]
#  [ 1 11 17 21 24 44]
#  [ 7  8 24 34 36 41]
#  [ 6 11 15 24 32 39]
#  [ 5 11 19 21 34 43]
#  [ 1  2  8 18 29 38]
#  [ 6  7 22 32 35 36]
#  [ 3  5 14 20 42 44]
#  [ 3 10 24 33 38 45]
#  [12 20 26 33 44 45]
#  [18 20 31 34 40 45]
#  [ 3  4  9 24 25 33]
#  [17 23 27 35 38 43]
#  [ 6  8 18 35 42 43]
#  [ 3  5 12 22 26 31]
#  [21 22 26 34 36 41]
#  [ 8 14 18 30 31 44]
#  [ 1  3 17 20 31 44]
#  [ 4  9 10 29 31 34]
#  [ 6 13 20 27 28 40]
#  [17 25 35 36 39 44]
#  [16 18 24 42 44 45]
#  [ 5 12 13 31 32 41]
#  [ 4 11 14 21 23 43]
#  [ 1 12 16 19 23 43]
#  [ 3  7 14 16 31 40]
#  [12 27 29 38 41 45]
#  [ 2 10 14 22 32 36]
#  [ 6  7 10 16 38 41]
#  [10 11 27 28 37 39]
#  [ 1  2  3  9 12 23]
#  [ 5 13 18 23 40 45]
#  [15 23 29 34 40 44]
#  [ 4  9 23 26 29 33]
#  [10 22 28 34 36 44]
#  [21 22 26 34 36 41]
#  [14 15 25 28 29 30]
#  [ 1  3 18 32 40 41]
#  [ 5  8 18 21 22 38]
#  [11 23 28 29 30 44]
#  [ 4  8 18 25 27 32]
#  [13 19 28 37 38 43]
#  [ 2 13 16 19 32 33]
#  [ 2  9 24 41 43 45]
#  [ 5  7 11 13 20 33]
#  [ 1  5 13 26 29 34]
#  [ 3  9 11 12 13 19]
#  [ 7 10 22 25 34 40]
#  [ 5 12 25 26 38 45]
#  [ 5 19 22 25 28 43]
#  [ 2  5 14 28 31 32]
#  [ 2  4 15 28 31 34]
#  [16 25 26 31 36 43]
#  [ 3 13 29 38 39 42]
#  [ 7  8 10 19 21 31]
#  [ 6 13 27 31 32 37]
#  [ 7  8 24 34 36 41]
#  [ 2  8 32 33 35 36]
#  [14 21 22 25 30 36]
#  [ 7 13 16 18 35 38]
#  [19 24 27 30 31 34]
#  [ 9 18 32 33 37 44]
#  [ 4  5  6 12 25 37]
#  [ 5 14 15 27 30 45]
#  [ 1  7 16 18 34 38]
#  [19 23 30 37 43 45]
#  [ 9 12 19 20 39 41]
#  [ 6  7  9 11 17 18]
#  [10 22 27 31 42 43]
#  [ 2 12 14 17 24 40]
#  [16 17 22 30 37 43]
#  [ 6  7 10 16 38 41]
#  [ 6 14 19 21 23 31]
#  [13 14 24 32 39 41]
#  [ 3 13 20 24 33 37]
#  [ 5  7 13 20 21 44]
#  [ 1  2  4 23 31 34]
#  [ 2  3 12 20 27 38]
#  [10 24 25 33 40 44]
#  [ 4 19 21 24 26 41]
#  [ 5  7 11 13 20 33]
#  [14 25 29 32 33 45]
#  [ 3  6 22 23 24 38]
#  [ 5  8 29 30 35 44]
#  [ 5 13 14 22 44 45]
#  [ 6  8 18 35 42 43]
#  [ 7 22 29 33 34 35]
#  [ 2  4 11 17 26 27]
#  [ 3  6 22 23 24 38]
#  [ 1 28 35 41 43 44]
#  [ 1  7 36 37 41 42]
#  [ 2 18 24 30 32 45]
#  [ 6 11 16 19 21 32]
#  [ 1 21 24 26 29 42]
#  [ 9 15 16 21 28 34]
#  [ 8 16 25 30 42 43]
#  [ 8 12 29 31 42 43]
#  [ 6 21 36 38 39 43]]
# RandomForest :  [[ 1  7 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1 11 13 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 19 31 34 45]
#  [ 1  7 19 31 34 45]
#  [ 1  7 20 27 34 45]
#  [ 1  7 18 26 39 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 18 27 34 45]
#  [ 1 11 19 31 39 45]
#  [ 1 11 18 22 28 45]
#  [ 1  7 19 27 34 45]
#  [ 1  7 19 31 34 45]
#  [ 1  7 19 23 34 45]
#  [ 1 11 19 31 34 45]
#  [ 1 12 20 27 39 45]
#  [ 1  7 18 27 34 45]
#  [ 1  7 20 27 34 45]
#  [ 1  7 13 31 34 45]
#  [ 1  7 20 26 34 45]
#  [ 1  7 20 27 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  7 20 27 34 45]
#  [ 1  7 18 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 27 34 45]
#  [ 1 11 20 27 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  8 19 31 34 45]
#  [ 1  7 20 27 34 45]
#  [ 1  7 18 31 34 45]
#  [ 1  7 19 31 34 45]
#  [ 1 11 13 31 39 45]
#  [ 1 11 13 27 39 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 19 31 34 45]
#  [ 1 11 18 26 34 45]
#  [ 1  7 18 27 34 45]
#  [ 1  7 13 31 34 45]
#  [ 1  7 18 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 13 27 34 45]
#  [ 1  8 19 27 34 45]
#  [ 1 10 13 27 39 45]
#  [ 1  7 13 31 39 45]
#  [ 1  8 19 27 34 45]
#  [ 1  7 20 27 34 45]
#  [ 1  7 18 27 34 45]
#  [ 1  7 20 27 39 45]
#  [ 1  7 18 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 13 27 34 45]
#  [ 1  7 24 26 34 45]
#  [ 1  7 18 27 34 45]
#  [ 1  7 18 31 34 45]
#  [ 1  7 19 31 34 45]
#  [ 1  7 18 27 34 45]
#  [ 1  7 18 31 34 45]
#  [ 1 11 15 27 39 45]
#  [ 1  8 19 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 27 34 45]
#  [ 1  7 18 27 34 45]
#  [ 1  7 19 31 34 45]
#  [ 1  8 19 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1 11 13 27 39 44]
#  [ 1 11 20 27 34 45]
#  [ 1  8 19 31 34 45]
#  [ 1  7 13 31 34 45]
#  [ 1 12 18 27 39 45]
#  [ 1  7 19 27 39 45]
#  [ 1  7 18 31 34 45]
#  [ 1  7 20 27 34 45]
#  [ 1  7 20 27 34 45]
#  [ 1  7 19 31 34 45]
#  [ 1  7 18 31 34 45]
#  [ 1  7 19 31 34 45]
#  [ 1  7 18 27 34 45]
#  [ 1 11 18 26 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 27 34 45]
#  [ 1  8 20 31 34 45]
#  [ 1  7 19 31 34 45]
#  [ 1  8 19 31 34 45]
#  [ 1 11 18 31 34 45]
#  [ 1  7 19 33 39 45]
#  [ 1  7 13 27 34 45]
#  [ 1  7 18 27 34 45]
#  [ 1  7 19 31 34 45]
#  [ 1  7 18 27 34 45]
#  [ 1  8 19 31 34 45]
#  [ 1  7 19 31 34 45]
#  [ 1  7 13 31 34 45]
#  [ 1 10 13 27 37 45]
#  [ 1  7 19 31 34 45]
#  [ 1 11 18 26 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  7 20 27 34 45]
#  [ 1  7 20 27 34 45]
#  [ 1  7 20 31 34 45]
#  [ 1  8 19 31 34 45]
#  [ 1  7 20 27 34 45]
#  [ 1  8 19 31 36 45]
#  [ 1  7 20 31 34 45]]

# %%
# 평가용 함수 - 분류
from sklearn.metrics import mean_squared_error

print(np.sqrt(mean_squared_error(yval, pred1)))
print(np.sqrt(mean_squared_error(yval, pred4)))
print(np.sqrt(mean_squared_error(yval, pred5)))
# Out:
# 7.727263814611616
# 9.141397678427053
# 7.916897923257109

# %%
# from sklearn.ensemble import RandomForestRegressor

# model = RandomForestRegressor(random_state = 202307,
#                               max_depth = 3,
#                               n_estimators= 5)
# model.fit(Xtr, ytr)

# rpred = model.predict(Xval)
# rpred

# %%
# from sklearn.metrics import mean_squared_error

# print(np.sqrt(mean_squared_error(yval, rpred)))

# %%
# from sklearn.ensemble import RandomForestClassifier

# model2 = RandomForestClassifier(random_state = 202307,
#                               max_depth = 5,
#                               n_estimators= 100)
# model2.fit(Xtr, ytr)

# rpred2 = model2.predict(Xval)
# rpred2

# %%
# from sklearn.metrics import roc_auc_score

# print(roc_auc_score(yval, rpred2))

# %%
pred = model1.predict(Xtest)
pred
# Out:
# array([[ 1, 11, 13, 25, 38, 45],
#        [ 1, 11, 13, 25, 38, 45],
#        [ 1, 11, 13, 26, 38, 45],
#        [ 1, 11, 13, 26, 38, 45],
#        [ 1, 11, 13, 25, 38, 45],
#        [ 1, 11, 13, 26, 38, 45],
#        [ 1, 11, 13, 25, 38, 45]])

# %%
from sklearn.neighbors import KNeighborsClassifier

model11 = KNeighborsClassifier(n_neighbors = 300,
                              leaf_size = 7)

model11.fit(Xtrain, ytrain)

kpred = model11.predict(Xtest)
kpred
# Out:
# array([[ 4, 11, 13, 26, 38, 45],
#        [ 4, 11, 13, 26, 38, 45],
#        [ 4, 11, 13, 26, 38, 45],
#        [ 4, 11, 13, 26, 38, 45],
#        [ 1, 11, 13, 26, 38, 45],
#        [ 4, 11, 13, 26, 38, 45],
#        [ 1, 11, 13, 26, 38, 45]])

# %%
predi = model4.predict(Xtest)
predi
# Out:
# array([[ 2,  6, 18, 21, 33, 34],
#        [ 2,  6, 18, 21, 33, 34],
#        [ 2,  6, 18, 21, 33, 34],
#        [ 2,  6, 18, 21, 33, 34],
#        [ 2,  6, 18, 21, 33, 34],
#        [ 2,  6, 18, 21, 33, 34],
#        [ 2,  6, 18, 21, 33, 34]])

# %%
from sklearn.tree import DecisionTreeClassifier

model44 = DecisionTreeClassifier(random_state = 202311,
                                max_depth = 50)
model44.fit(Xtrain, ytrain)

dpred = model44.predict(Xtest)
dpred
# Out:
# array([[11, 12, 18, 21, 31, 38],
#        [11, 12, 18, 21, 31, 38],
#        [11, 12, 18, 21, 31, 38],
#        [11, 12, 18, 21, 31, 38],
#        [11, 12, 18, 21, 31, 38],
#        [11, 12, 18, 21, 31, 38],
#        [11, 12, 18, 21, 31, 38]])

# %%
predo = model5.predict(Xtest)
predo
# Out:
# array([[ 4, 10, 24, 22, 28, 33],
#        [ 4, 10, 24, 22, 28, 33],
#        [ 4, 10, 24, 22, 28, 33],
#        [ 4, 10, 24, 22, 28, 33],
#        [ 4, 10, 24, 22, 28, 33],
#        [ 4, 10, 24, 22, 28, 33],
#        [ 4, 10, 24, 22, 28, 33]])

# %%
from sklearn.ensemble import RandomForestRegressor

model55 = RandomForestClassifier(random_state = 202311,
                                max_depth = 2,
                                n_estimators= 60)
model55.fit(Xtrain, ytrain)

rpred = model55.predict(Xtest)
rpred
# Out:
# array([[ 4, 12, 18, 22, 28, 33],
#        [ 4, 12, 18, 22, 28, 33],
#        [ 4, 12, 18, 22, 28, 33],
#        [ 4, 12, 18, 22, 28, 33],
#        [ 4, 12, 18, 22, 28, 33],
#        [ 4, 12, 18, 22, 28, 33],
#        [ 4, 12, 18, 22, 28, 33]])
